# %% [markdown]
# # **INFO5731 Assignment 2**
#
# In this assignment, you will work on gathering text data from an open data source via web scraping or API. Following this, you will need to clean the text data and perform syntactic analysis on the data. Follow the instructions carefully and design well-structured Python programs to address each question.
#
# **Expectations**:
# *   Use the provided .*ipynb* document to write your code & respond to the questions. Avoid generating a new file.
# *   Write complete answers and run all the cells before submission.
# *   Make sure the submission is "clean"; *i.e.*, no unnecessary code cells.
# *   Once finished, allow shared rights from top right corner (*see Canvas for details*).
#
# * **Make sure to submit the cleaned data CSV in the comment section - 10 points**
#
# **Total points**: 100
#
# **Deadline**: Wednesday, at 11:59 PM.
#
# **Late Submission will have a penalty of 10% reduction for each day after the deadline.**

# %% [markdown]
# # Question 1 (40 points)
#
# Write a python program to collect text data from **either of the following sources** and save the data into a **csv file:**
#
# (1) Collect all the customer reviews of a product (you can choose any porduct) on amazon. [atleast 1000 reviews]
#
# (2) Collect the top 1000 User Reviews of a movie recently in 2023 or 2024 (you can choose any movie) from IMDB. [If one movie doesn't have sufficient reviews, collect reviews of atleast 2 or 3 movies]
#
# (3) Collect all the reviews of the top 1000 most popular software from G2 or Capterra.
#
# (4) Collect the **abstracts** of the top 10000 research papers by using the query "machine learning", "data science", "artifical intelligence", or "information extraction" from Semantic Scholar.
#
# (5) Collect all the information of the 904 narrators in the Densho Digital Repository.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = 'https://www.imdb.com/title/tt0137523/reviews/?ref_=tt_ov_rt'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}
response = requests.get(url, headers=headers)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    load_more_button = soup.find('div', class_='load-more-data')
    reviews = []
    while load_more_button and len(reviews) < 1000:
        data_key = load_more_button['data-key']
        load_more_url = f"https://www.imdb.com/title/tt0137523/reviews/_ajax?ajax=1&ref_=undefined&paginationKey={data_key}"
        response = requests.get(load_more_url, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        review_elements = soup.find_all('div', class_='review-container')
        for review_element in review_elements:
            review_text = review_element.find('div', class_='text show-more__control').get_text(strip=True)
            reviews.append(review_text)
        load_more_button = soup.find('div', class_='load-more-data')
    if reviews:
        df = pd.DataFrame({'Review': reviews})
        df.to_csv('1000_reviews.csv', index=False)
        print("Reviews saved to 1000_reviews.csv")
    else:
        print("No reviews found.")
else:
    print("Error accessing movie page:", response.status_code)
# Out:
# Reviews saved to 1000_reviews.csv

# %% [markdown]
# # Question 2 (30 points)
#
# Write a python program to **clean the text data** you collected in the previous question and save the clean data in a new column in the csv file. The data cleaning steps include: [Code and output is required for each part]
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the stopwords list.
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
# Write code for each of the sub parts with proper comments.

import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
import string

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

#Reading the dataset which is collected in the previous question.
df = pd.read_csv('1000_reviews.csv')

# Function to clean text data
def clean_text(text):
  print("Original Text: ")
  print(text)

# Step 1: Removing Noise such as sepcial characters and punctuations
  text = ''.join([char for char in text if char not in string.punctuation])
  print(" ")
  print("Step 1: Result after removing special characters and punctuation is: ")
  print(text)

# Step 2: Remove numbers
  text = ''.join([char for char in text if not char.isdigit()])
  print(" ")
  print("Step 2: Result after removing numbers in the text is: ")
  print(text)

# Step 3: Tokenizing text and removing stop words
  tokens = word_tokenize(text)
  stop_words = set(stopwords.words('english'))
  tokens = [word for word in tokens if word not in stop_words]
  print(" ")
  print("Step 3: Result after tokenizing and removing stopwords: ")
  print(tokens)

# Step 4: Tranforming all sentences into lowercase text
  text = text.lower()
  print(" ")
  print("Step 4: LowerCase text is: ")
  print(text)

# Step 5: Stemming
  stemmer = PorterStemmer()
  stemmed_tokens = [stemmer.stem(word) for word in tokens]
  print(" ")
  print("Step 5: Ouput of the text after stemming is: ")
  print(stemmed_tokens)

# Step 6: Lemmatization
  lemmatizer = WordNetLemmatizer()
  lemmatized_tokens = [lemmatizer.lemmatize(word) for word in tokens]
  print(" ")
  print("Step 6: Result after Lemmatization is: ")
  print(lemmatized_tokens)
  print(" ")

# Joining tokens back into text to obtain cleaned version of original text
  cleaned_text = ' '.join(lemmatized_tokens)
  return cleaned_text

# Applying data cleaning to the 'Review' column
df['Cleaned_Review'] = df['Review'].apply(clean_text)

# Saving the cleaned data to a new column in the CSV file
df.to_csv('1000_reviews_cleaned.csv', index=False)
print("Cleaned data saved to 1000_reviews_cleaned.csv")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Streaming output truncated to the last 5000 lines.
# Original Text:
# David Fincher's cult classic has transcended its popularity upon its initial release to become etched into the fabric of pop culture, to the point where almost any stranger on the street would know the first two rules of 'Fight Club.'Where 'Fight Club' succeeds is in its originality. From the witty dialogue to the Tarantino-esque editing style and the character evolution, the part-time drama, part-time dark comedy is a portrait of a man who experiences an existential crisis and incidentally creates a movement. The duo of Edward Norton and Brad Pitt are iconic, as they couldn't be any more of an odd couple. Their "oil and water" dynamic is a major reason for why 'Fight Club' works - they are able to find function in a dysfunctional world.But it's not just the Norton and Pitt show. The "third wheel" that is Marla Singer (Helena Bonham Carter) is perfectly cast as a kooky free spirit whose temper is as short as her hair. Together, the three A-list actors deliver a trifecta of dramatic performances that still to this day are career highlights.Sure, 'Fight Club' feels a bit dated at times. But the story, execution and cast have ensured the film has and will continue to stand the test of time.
#
# Step 1: Result after removing special characters and punctuation is:
# David Finchers cult classic has transcended its popularity upon its initial release to become etched into the fabric of pop culture to the point where almost any stranger on the street would know the first two rules of Fight ClubWhere Fight Club succeeds is in its originality From the witty dialogue to the Tarantinoesque editing style and the character evolution the parttime drama parttime dark comedy is a portrait of a man who experiences an existential crisis and incidentally creates a movement The duo of Edward Norton and Brad Pitt are iconic as they couldnt be any more of an odd couple Their oil and water dynamic is a major reason for why Fight Club works  they are able to find function in a dysfunctional worldBut its not just the Norton and Pitt show The third wheel that is Marla Singer Helena Bonham Carter is perfectly cast as a kooky free spirit whose temper is as short as her hair Together the three Alist actors deliver a trifecta of dramatic performances that still to this day are career highlightsSure Fight Club feels a bit dated at times But the story execution and cast have ensured the film has and will continue to stand the test of time
#
# Step 2: Result after removing numbers in the text is:
# David Finchers cult classic has transcended its popularity upon its initial release to become etched into the fabric of pop culture to the point where almost any stranger on the street would know the first two rules of Fight ClubWhere Fight Club succeeds is in its originality From the witty dialogue to the Tarantinoesque editing style and the character evolution the parttime drama parttime dark comedy is a portrait of a man who experiences an existential crisis and incidentally creates a movement The duo of Edward Norton and Brad Pitt are iconic as they couldnt be any more of an odd couple Their oil and water dynamic is a major reason for why Fight Club works  they are able to find function in a dysfunctional worldBut its not just the Norton and Pitt show The third wheel that is Marla Singer Helena Bonham Carter is perfectly cast as a kooky free spirit whose temper is as short as her hair Together the three Alist actors deliver a trifecta of dramatic performances that still to this day are career highlightsSure Fight Club feels a bit dated at times But the story execution and cast have ensured the film has and will continue to stand the test of time
#
# Step 3: Result after tokenizing and removing stopwords:
# ['David', 'Finchers', 'cult', 'classic', 'transcended', 'popularity', 'upon', 'initial', 'release', 'become', 'etched', 'fabric', 'pop', 'culture', 'point', 'almost', 'stranger', 'street', 'would', 'know', 'first', 'two', 'rules', 'Fight', 'ClubWhere', 'Fight', 'Club', 'succeeds', 'originality', 'From', 'witty', 'dialogue', 'Tarantinoesque', 'editing', 'style', 'character', 'evolution', 'parttime', 'drama', 'parttime', 'dark', 'comedy', 'portrait', 'man', 'experiences', 'existential', 'crisis', 'incidentally', 'creates', 'movement', 'The', 'duo', 'Edward', 'Norton', 'Brad', 'Pitt', 'iconic', 'couldnt', 'odd', 'couple', 'Their', 'oil', 'water', 'dynamic', 'major', 'reason', 'Fight', 'Club', 'works', 'able', 'find', 'function', 'dysfunctional', 'worldBut', 'Norton', 'Pitt', 'show', 'The', 'third', 'wheel', 'Marla', 'Singer', 'Helena', 'Bonham', 'Carter', 'perfectly', 'cast', 'kooky', 'free', 'spirit', 'whose', 'temper', 'short', 'hair', 'Together', 'three', 'Alist', 'actors', 'deliver', 'trifecta', 'dramatic', 'performances', 'still', 'day', 'career', 'highlightsSure', 'Fight', 'Club', 'feels', 'bit', 'dated', 'times', 'But', 'story', 'execution', 'cast', 'ensured', 'film', 'continue', 'stand', 'test', 'time']
#
# Step 4: LowerCase text is:
# david finchers cult classic has transcended its popularity upon its initial release to become etched into the fabric of pop culture to the point where almost any stranger on the street would know the first two rules of fight clubwhere fight club succeeds is in its originality from the witty dialogue to the tarantinoesque editing style and the character evolution the parttime drama parttime dark comedy is a portrait of a man who experiences an existential crisis and incidentally creates a movement the duo of edward norton and brad pitt are iconic as they couldnt be any more of an odd couple their oil and water dynamic is a major reason for why fight club works  they are able to find function in a dysfunctional worldbut its not just the norton and pitt show the third wheel that is marla singer helena bonham carter is perfectly cast as a kooky free spirit whose temper is as short as her hair together the three alist actors deliver a trifecta of dramatic performances that still to this day are career highlightssure fight club feels a bit dated at times but the story execution and cast have ensured the film has and will continue to stand the test of time
#
# Step 5: Ouput of the text after stemming is:
# ['david', 'fincher', 'cult', 'classic', 'transcend', 'popular', 'upon', 'initi', 'releas', 'becom', 'etch', 'fabric', 'pop', 'cultur', 'point', 'almost', 'stranger', 'street', 'would', 'know', 'first', 'two', 'rule', 'fight', 'clubwher', 'fight', 'club', 'succe', 'origin', 'from', 'witti', 'dialogu', 'tarantinoesqu', 'edit', 'style', 'charact', 'evolut', 'parttim', 'drama', 'parttim', 'dark', 'comedi', 'portrait', 'man', 'experi', 'existenti', 'crisi', 'incident', 'creat', 'movement', 'the', 'duo', 'edward', 'norton', 'brad', 'pitt', 'icon', 'couldnt', 'odd', 'coupl', 'their', 'oil', 'water', 'dynam', 'major', 'reason', 'fight', 'club', 'work', 'abl', 'find', 'function', 'dysfunct', 'worldbut', 'norton', 'pitt', 'show', 'the', 'third', 'wheel', 'marla', 'singer', 'helena', 'bonham', 'carter', 'perfectli', 'cast', 'kooki', 'free', 'spirit', 'whose', 'temper', 'short', 'hair', 'togeth', 'three', 'alist', 'actor', 'deliv', 'trifecta', 'dramat', 'perform', 'still', 'day', 'career', 'highlightssur', 'fight', 'club', 'feel', 'bit', 'date', 'time', 'but', 'stori', 'execut', 'cast', 'ensur', 'film', 'continu', 'stand', 'test', 'time']
#
# Step 6: Result after Lemmatization is:
# ['David', 'Finchers', 'cult', 'classic', 'transcended', 'popularity', 'upon', 'initial', 'release', 'become', 'etched', 'fabric', 'pop', 'culture', 'point', 'almost', 'stranger', 'street', 'would', 'know', 'first', 'two', 'rule', 'Fight', 'ClubWhere', 'Fight', 'Club', 'succeeds', 'originality', 'From', 'witty', 'dialogue', 'Tarantinoesque', 'editing', 'style', 'character', 'evolution', 'parttime', 'drama', 'parttime', 'dark', 'comedy', 'portrait', 'man', 'experience', 'existential', 'crisis', 'incidentally', 'creates', 'movement', 'The', 'duo', 'Edward', 'Norton', 'Brad', 'Pitt', 'iconic', 'couldnt', 'odd', 'couple', 'Their', 'oil', 'water', 'dynamic', 'major', 'reason', 'Fight', 'Club', 'work', 'able', 'find', 'function', 'dysfunctional', 'worldBut', 'Norton', 'Pitt', 'show', 'The', 'third', 'wheel', 'Marla', 'Singer', 'Helena', 'Bonham', 'Carter', 'perfectly', 'cast', 'kooky', 'free', 'spirit', 'whose', 'temper', 'short', 'hair', 'Together', 'three', 'Alist', 'actor', 'deliver', 'trifecta', 'dramatic', 'performance', 'still', 'day', 'career', 'highlightsSure', 'Fight', 'Club', 'feel', 'bit', 'dated', 'time', 'But', 'story', 'execution', 'cast', 'ensured', 'film', 'continue', 'stand', 'test', 'time']
#
# Original Text:
# FIGHT CLUB / (1999) ***Viewing "Fight Club," the new drama by assertive director David Fincher, is like walking through graffiti-laden streets of a crime-ridden suburban city; it is dark, brutal, gritty, troublesome, and hostile. This film is all of those things, but in this circumstance I use such adjectives to the production's credit. "Fight Club" is a coarse, unpleasing journey into the lives of its narcotic characters, but it is for those exact same reasons why I find myself recommending the movie to audiences with strong stomachs. If this film was anything but what I have already described, we would be appalled at such deserving controversy and violent content contained. The hostility of  "Fight Club" is the main factor of which why it succeeds; the raucous style contributes in making a convincing, entertaining, and recklessly original story.Edward Norton stars as the movie's narrator, an insomniac spending his petty days working in an office and sleepless nights seeking out clinics in which he provides comfort to those less fortunate than he. One of the people he meets is an overweight but gentle pedestrian named Robert Paulson (Meat Loaf), a victim of testicular cancer. He also meets a sleazy, foul-mouthed drifter like himself named Marla Singer (Helena Bonham Carter).Norton's character development is quite unusual; although effective and versatile, the introduction, as is with the rest of the movie, is extremely bleak. It is as if the characters are creating an anti-society story through some perverse behaviors. We witness the movie through the Narrator's point of view, who ends up explaining more of the plot than necessary.During a plane flight, our undervalued narrator encounters a cocky and well-dressed soap sales representative named Tyler Durden (Brat Pit), whose sarcastic and outspoken notions create a charisma between both individuals. Shortly afterwards, the Narrator's apartment blows apart, leaving him nowhere to seek shelter but with Tyler. This enigmatic man then organizes an underground sensation called Fight Club, in which young men inquire pleasure out of beating each other into bloody carnage. This secret society, located in the basement of a local bar, allows its members to find self-discovery and freedom through brawls and scuffles."Fight Club" is crafted stirringly from structured innovation to production designs. Art director Chris Gorak, production designer Alex McDowell, and cinematographer Jeff Cornenweth capture the film's subversive atmosphere with vivid detail and descriptive style and dazzling lighting techniques. Costume designs by Michael Kaplan contribute to the development of Tyler Durden with distinctive, creative outfits.David Fincher is currently one of my favorite directors. His striking and suspenseful thrillers "The Game" and "Seven" captured my attention thoroughly with sharp characters and focused narratives. "The Game" detailed a wealthy executive immersed in confederacy who must overcome a variety of challenges to survive. "Fight Club" is more or less the same topic, in which a rebellious benefactor assists in taking charge of his lack of freedom through violent encounters. This production contains plot twists and a climatic resolution that may require more reasoning and thought than the majority of an audience will be willing to submit."Fight Club" contains enough extreme graphic violent content for several movies, yet few characters end up with severe injuries. When a tough young man beats someone's face into the ground, resulting in so much gore he is hardly recognizable, you would expect that person to end up in critical condition at the hospital. However, many characters in this movie engage in uncultivated attacks but appear in modest condition the following day. I guess this movie centers more on its theme than the character's actual course of action, which is obligatory for success.Brad Pitt captures Tyler Durden with a macho, politically incorrect attitude; he is the rig ...
#
# Step 1: Result after removing special characters and punctuation is:
# FIGHT CLUB  1999 Viewing Fight Club the new drama by assertive director David Fincher is like walking through graffitiladen streets of a crimeridden suburban city it is dark brutal gritty troublesome and hostile This film is all of those things but in this circumstance I use such adjectives to the productions credit Fight Club is a coarse unpleasing journey into the lives of its narcotic characters but it is for those exact same reasons why I find myself recommending the movie to audiences with strong stomachs If this film was anything but what I have already described we would be appalled at such deserving controversy and violent content contained The hostility of  Fight Club is the main factor of which why it succeeds the raucous style contributes in making a convincing entertaining and recklessly original storyEdward Norton stars as the movies narrator an insomniac spending his petty days working in an office and sleepless nights seeking out clinics in which he provides comfort to those less fortunate than he One of the people he meets is an overweight but gentle pedestrian named Robert Paulson Meat Loaf a victim of testicular cancer He also meets a sleazy foulmouthed drifter like himself named Marla Singer Helena Bonham CarterNortons character development is quite unusual although effective and versatile the introduction as is with the rest of the movie is extremely bleak It is as if the characters are creating an antisociety story through some perverse behaviors We witness the movie through the Narrators point of view who ends up explaining more of the plot than necessaryDuring a plane flight our undervalued narrator encounters a cocky and welldressed soap sales representative named Tyler Durden Brat Pit whose sarcastic and outspoken notions create a charisma between both individuals Shortly afterwards the Narrators apartment blows apart leaving him nowhere to seek shelter but with Tyler This enigmatic man then organizes an underground sensation called Fight Club in which young men inquire pleasure out of beating each other into bloody carnage This secret society located in the basement of a local bar allows its members to find selfdiscovery and freedom through brawls and scufflesFight Club is crafted stirringly from structured innovation to production designs Art director Chris Gorak production designer Alex McDowell and cinematographer Jeff Cornenweth capture the films subversive atmosphere with vivid detail and descriptive style and dazzling lighting techniques Costume designs by Michael Kaplan contribute to the development of Tyler Durden with distinctive creative outfitsDavid Fincher is currently one of my favorite directors His striking and suspenseful thrillers The Game and Seven captured my attention thoroughly with sharp characters and focused narratives The Game detailed a wealthy executive immersed in confederacy who must overcome a variety of challenges to survive Fight Club is more or less the same topic in which a rebellious benefactor assists in taking charge of his lack of freedom through violent encounters This production contains plot twists and a climatic resolution that may require more reasoning and thought than the majority of an audience will be willing to submitFight Club contains enough extreme graphic violent content for several movies yet few characters end up with severe injuries When a tough young man beats someones face into the ground resulting in so much gore he is hardly recognizable you would expect that person to end up in critical condition at the hospital However many characters in this movie engage in uncultivated attacks but appear in modest condition the following day I guess this movie centers more on its theme than the characters actual course of action which is obligatory for successBrad Pitt captures Tyler Durden with a macho politically incorrect attitude he is the right choice for his character with a hunky physical appearance and appropriate style this is one of the actors ca ...
#
# Step 2: Result after removing numbers in the text is:
# FIGHT CLUB   Viewing Fight Club the new drama by assertive director David Fincher is like walking through graffitiladen streets of a crimeridden suburban city it is dark brutal gritty troublesome and hostile This film is all of those things but in this circumstance I use such adjectives to the productions credit Fight Club is a coarse unpleasing journey into the lives of its narcotic characters but it is for those exact same reasons why I find myself recommending the movie to audiences with strong stomachs If this film was anything but what I have already described we would be appalled at such deserving controversy and violent content contained The hostility of  Fight Club is the main factor of which why it succeeds the raucous style contributes in making a convincing entertaining and recklessly original storyEdward Norton stars as the movies narrator an insomniac spending his petty days working in an office and sleepless nights seeking out clinics in which he provides comfort to those less fortunate than he One of the people he meets is an overweight but gentle pedestrian named Robert Paulson Meat Loaf a victim of testicular cancer He also meets a sleazy foulmouthed drifter like himself named Marla Singer Helena Bonham CarterNortons character development is quite unusual although effective and versatile the introduction as is with the rest of the movie is extremely bleak It is as if the characters are creating an antisociety story through some perverse behaviors We witness the movie through the Narrators point of view who ends up explaining more of the plot than necessaryDuring a plane flight our undervalued narrator encounters a cocky and welldressed soap sales representative named Tyler Durden Brat Pit whose sarcastic and outspoken notions create a charisma between both individuals Shortly afterwards the Narrators apartment blows apart leaving him nowhere to seek shelter but with Tyler This enigmatic man then organizes an underground sensation called Fight Club in which young men inquire pleasure out of beating each other into bloody carnage This secret society located in the basement of a local bar allows its members to find selfdiscovery and freedom through brawls and scufflesFight Club is crafted stirringly from structured innovation to production designs Art director Chris Gorak production designer Alex McDowell and cinematographer Jeff Cornenweth capture the films subversive atmosphere with vivid detail and descriptive style and dazzling lighting techniques Costume designs by Michael Kaplan contribute to the development of Tyler Durden with distinctive creative outfitsDavid Fincher is currently one of my favorite directors His striking and suspenseful thrillers The Game and Seven captured my attention thoroughly with sharp characters and focused narratives The Game detailed a wealthy executive immersed in confederacy who must overcome a variety of challenges to survive Fight Club is more or less the same topic in which a rebellious benefactor assists in taking charge of his lack of freedom through violent encounters This production contains plot twists and a climatic resolution that may require more reasoning and thought than the majority of an audience will be willing to submitFight Club contains enough extreme graphic violent content for several movies yet few characters end up with severe injuries When a tough young man beats someones face into the ground resulting in so much gore he is hardly recognizable you would expect that person to end up in critical condition at the hospital However many characters in this movie engage in uncultivated attacks but appear in modest condition the following day I guess this movie centers more on its theme than the characters actual course of action which is obligatory for successBrad Pitt captures Tyler Durden with a macho politically incorrect attitude he is the right choice for his character with a hunky physical appearance and appropriate style this is one of the actors career ...
#
# Step 3: Result after tokenizing and removing stopwords:
# ['FIGHT', 'CLUB', 'Viewing', 'Fight', 'Club', 'new', 'drama', 'assertive', 'director', 'David', 'Fincher', 'like', 'walking', 'graffitiladen', 'streets', 'crimeridden', 'suburban', 'city', 'dark', 'brutal', 'gritty', 'troublesome', 'hostile', 'This', 'film', 'things', 'circumstance', 'I', 'use', 'adjectives', 'productions', 'credit', 'Fight', 'Club', 'coarse', 'unpleasing', 'journey', 'lives', 'narcotic', 'characters', 'exact', 'reasons', 'I', 'find', 'recommending', 'movie', 'audiences', 'strong', 'stomachs', 'If', 'film', 'anything', 'I', 'already', 'described', 'would', 'appalled', 'deserving', 'controversy', 'violent', 'content', 'contained', 'The', 'hostility', 'Fight', 'Club', 'main', 'factor', 'succeeds', 'raucous', 'style', 'contributes', 'making', 'convincing', 'entertaining', 'recklessly', 'original', 'storyEdward', 'Norton', 'stars', 'movies', 'narrator', 'insomniac', 'spending', 'petty', 'days', 'working', 'office', 'sleepless', 'nights', 'seeking', 'clinics', 'provides', 'comfort', 'less', 'fortunate', 'One', 'people', 'meets', 'overweight', 'gentle', 'pedestrian', 'named', 'Robert', 'Paulson', 'Meat', 'Loaf', 'victim', 'testicular', 'cancer', 'He', 'also', 'meets', 'sleazy', 'foulmouthed', 'drifter', 'like', 'named', 'Marla', 'Singer', 'Helena', 'Bonham', 'CarterNortons', 'character', 'development', 'quite', 'unusual', 'although', 'effective', 'versatile', 'introduction', 'rest', 'movie', 'extremely', 'bleak', 'It', 'characters', 'creating', 'antisociety', 'story', 'perverse', 'behaviors', 'We', 'witness', 'movie', 'Narrators', 'point', 'view', 'ends', 'explaining', 'plot', 'necessaryDuring', 'plane', 'flight', 'undervalued', 'narrator', 'encounters', 'cocky', 'welldressed', 'soap', 'sales', 'representative', 'named', 'Tyler', 'Durden', 'Brat', 'Pit', 'whose', 'sarcastic', 'outspoken', 'notions', 'create', 'charisma', 'individuals', 'Shortly', 'afterwards', 'Narrators', 'apartment', 'blows', 'apart', 'leaving', 'nowhere', 'seek', 'shelter', 'Tyler', 'This', 'enigmatic', 'man', 'organizes', 'underground', 'sensation', 'called', 'Fight', 'Club', 'young', 'men', 'inquire', 'pleasure', 'beating', 'bloody', 'carnage', 'This', 'secret', 'society', 'located', 'basement', 'local', 'bar', 'allows', 'members', 'find', 'selfdiscovery', 'freedom', 'brawls', 'scufflesFight', 'Club', 'crafted', 'stirringly', 'structured', 'innovation', 'production', 'designs', 'Art', 'director', 'Chris', 'Gorak', 'production', 'designer', 'Alex', 'McDowell', 'cinematographer', 'Jeff', 'Cornenweth', 'capture', 'films', 'subversive', 'atmosphere', 'vivid', 'detail', 'descriptive', 'style', 'dazzling', 'lighting', 'techniques', 'Costume', 'designs', 'Michael', 'Kaplan', 'contribute', 'development', 'Tyler', 'Durden', 'distinctive', 'creative', 'outfitsDavid', 'Fincher', 'currently', 'one', 'favorite', 'directors', 'His', 'striking', 'suspenseful', 'thrillers', 'The', 'Game', 'Seven', 'captured', 'attention', 'thoroughly', 'sharp', 'characters', 'focused', 'narratives', 'The', 'Game', 'detailed', 'wealthy', 'executive', 'immersed', 'confederacy', 'must', 'overcome', 'variety', 'challenges', 'survive', 'Fight', 'Club', 'less', 'topic', 'rebellious', 'benefactor', 'assists', 'taking', 'charge', 'lack', 'freedom', 'violent', 'encounters', 'This', 'production', 'contains', 'plot', 'twists', 'climatic', 'resolution', 'may', 'require', 'reasoning', 'thought', 'majority', 'audience', 'willing', 'submitFight', 'Club', 'contains', 'enough', 'extreme', 'graphic', 'violent', 'content', 'several', 'movies', 'yet', 'characters', 'end', 'severe', 'injuries', 'When', 'tough', 'young', 'man', 'beats', 'someones', 'face', 'ground', 'resulting', 'much', 'gore', 'hardly', 'recognizable', 'would', 'expect', 'person', 'end', 'critical', 'condition', 'hospital', 'However', 'many', 'characters', 'movie', 'engage', 'uncultivated', 'attacks', 'appear', 'modest', 'condition', 'following', 'day', 'I', 'guess', 'movie', 'centers', 'theme', 'characters', 'actual', 'course', ' ...
#
# Step 4: LowerCase text is:
# fight club   viewing fight club the new drama by assertive director david fincher is like walking through graffitiladen streets of a crimeridden suburban city it is dark brutal gritty troublesome and hostile this film is all of those things but in this circumstance i use such adjectives to the productions credit fight club is a coarse unpleasing journey into the lives of its narcotic characters but it is for those exact same reasons why i find myself recommending the movie to audiences with strong stomachs if this film was anything but what i have already described we would be appalled at such deserving controversy and violent content contained the hostility of  fight club is the main factor of which why it succeeds the raucous style contributes in making a convincing entertaining and recklessly original storyedward norton stars as the movies narrator an insomniac spending his petty days working in an office and sleepless nights seeking out clinics in which he provides comfort to those less fortunate than he one of the people he meets is an overweight but gentle pedestrian named robert paulson meat loaf a victim of testicular cancer he also meets a sleazy foulmouthed drifter like himself named marla singer helena bonham carternortons character development is quite unusual although effective and versatile the introduction as is with the rest of the movie is extremely bleak it is as if the characters are creating an antisociety story through some perverse behaviors we witness the movie through the narrators point of view who ends up explaining more of the plot than necessaryduring a plane flight our undervalued narrator encounters a cocky and welldressed soap sales representative named tyler durden brat pit whose sarcastic and outspoken notions create a charisma between both individuals shortly afterwards the narrators apartment blows apart leaving him nowhere to seek shelter but with tyler this enigmatic man then organizes an underground sensation called fight club in which young men inquire pleasure out of beating each other into bloody carnage this secret society located in the basement of a local bar allows its members to find selfdiscovery and freedom through brawls and scufflesfight club is crafted stirringly from structured innovation to production designs art director chris gorak production designer alex mcdowell and cinematographer jeff cornenweth capture the films subversive atmosphere with vivid detail and descriptive style and dazzling lighting techniques costume designs by michael kaplan contribute to the development of tyler durden with distinctive creative outfitsdavid fincher is currently one of my favorite directors his striking and suspenseful thrillers the game and seven captured my attention thoroughly with sharp characters and focused narratives the game detailed a wealthy executive immersed in confederacy who must overcome a variety of challenges to survive fight club is more or less the same topic in which a rebellious benefactor assists in taking charge of his lack of freedom through violent encounters this production contains plot twists and a climatic resolution that may require more reasoning and thought than the majority of an audience will be willing to submitfight club contains enough extreme graphic violent content for several movies yet few characters end up with severe injuries when a tough young man beats someones face into the ground resulting in so much gore he is hardly recognizable you would expect that person to end up in critical condition at the hospital however many characters in this movie engage in uncultivated attacks but appear in modest condition the following day i guess this movie centers more on its theme than the characters actual course of action which is obligatory for successbrad pitt captures tyler durden with a macho politically incorrect attitude he is the right choice for his character with a hunky physical appearance and appropriate style this is one of the actors career ...
#
# Step 5: Ouput of the text after stemming is:
# ['fight', 'club', 'view', 'fight', 'club', 'new', 'drama', 'assert', 'director', 'david', 'fincher', 'like', 'walk', 'graffitiladen', 'street', 'crimeridden', 'suburban', 'citi', 'dark', 'brutal', 'gritti', 'troublesom', 'hostil', 'thi', 'film', 'thing', 'circumst', 'i', 'use', 'adject', 'product', 'credit', 'fight', 'club', 'coars', 'unpleas', 'journey', 'live', 'narcot', 'charact', 'exact', 'reason', 'i', 'find', 'recommend', 'movi', 'audienc', 'strong', 'stomach', 'if', 'film', 'anyth', 'i', 'alreadi', 'describ', 'would', 'appal', 'deserv', 'controversi', 'violent', 'content', 'contain', 'the', 'hostil', 'fight', 'club', 'main', 'factor', 'succe', 'raucou', 'style', 'contribut', 'make', 'convinc', 'entertain', 'recklessli', 'origin', 'storyedward', 'norton', 'star', 'movi', 'narrat', 'insomniac', 'spend', 'petti', 'day', 'work', 'offic', 'sleepless', 'night', 'seek', 'clinic', 'provid', 'comfort', 'less', 'fortun', 'one', 'peopl', 'meet', 'overweight', 'gentl', 'pedestrian', 'name', 'robert', 'paulson', 'meat', 'loaf', 'victim', 'testicular', 'cancer', 'he', 'also', 'meet', 'sleazi', 'foulmouth', 'drifter', 'like', 'name', 'marla', 'singer', 'helena', 'bonham', 'carternorton', 'charact', 'develop', 'quit', 'unusu', 'although', 'effect', 'versatil', 'introduct', 'rest', 'movi', 'extrem', 'bleak', 'it', 'charact', 'creat', 'antisocieti', 'stori', 'pervers', 'behavior', 'we', 'wit', 'movi', 'narrat', 'point', 'view', 'end', 'explain', 'plot', 'necessarydur', 'plane', 'flight', 'undervalu', 'narrat', 'encount', 'cocki', 'welldress', 'soap', 'sale', 'repres', 'name', 'tyler', 'durden', 'brat', 'pit', 'whose', 'sarcast', 'outspoken', 'notion', 'creat', 'charisma', 'individu', 'shortli', 'afterward', 'narrat', 'apart', 'blow', 'apart', 'leav', 'nowher', 'seek', 'shelter', 'tyler', 'thi', 'enigmat', 'man', 'organ', 'underground', 'sensat', 'call', 'fight', 'club', 'young', 'men', 'inquir', 'pleasur', 'beat', 'bloodi', 'carnag', 'thi', 'secret', 'societi', 'locat', 'basement', 'local', 'bar', 'allow', 'member', 'find', 'selfdiscoveri', 'freedom', 'brawl', 'scufflesfight', 'club', 'craft', 'stirringli', 'structur', 'innov', 'product', 'design', 'art', 'director', 'chri', 'gorak', 'product', 'design', 'alex', 'mcdowel', 'cinematograph', 'jeff', 'cornenweth', 'captur', 'film', 'subvers', 'atmospher', 'vivid', 'detail', 'descript', 'style', 'dazzl', 'light', 'techniqu', 'costum', 'design', 'michael', 'kaplan', 'contribut', 'develop', 'tyler', 'durden', 'distinct', 'creativ', 'outfitsdavid', 'fincher', 'current', 'one', 'favorit', 'director', 'hi', 'strike', 'suspens', 'thriller', 'the', 'game', 'seven', 'captur', 'attent', 'thoroughli', 'sharp', 'charact', 'focus', 'narr', 'the', 'game', 'detail', 'wealthi', 'execut', 'immers', 'confederaci', 'must', 'overcom', 'varieti', 'challeng', 'surviv', 'fight', 'club', 'less', 'topic', 'rebelli', 'benefactor', 'assist', 'take', 'charg', 'lack', 'freedom', 'violent', 'encount', 'thi', 'product', 'contain', 'plot', 'twist', 'climat', 'resolut', 'may', 'requir', 'reason', 'thought', 'major', 'audienc', 'will', 'submitfight', 'club', 'contain', 'enough', 'extrem', 'graphic', 'violent', 'content', 'sever', 'movi', 'yet', 'charact', 'end', 'sever', 'injuri', 'when', 'tough', 'young', 'man', 'beat', 'someon', 'face', 'ground', 'result', 'much', 'gore', 'hardli', 'recogniz', 'would', 'expect', 'person', 'end', 'critic', 'condit', 'hospit', 'howev', 'mani', 'charact', 'movi', 'engag', 'uncultiv', 'attack', 'appear', 'modest', 'condit', 'follow', 'day', 'i', 'guess', 'movi', 'center', 'theme', 'charact', 'actual', 'cours', 'action', 'obligatori', 'successbrad', 'pitt', 'captur', 'tyler', 'durden', 'macho', 'polit', 'incorrect', 'attitud', 'right', 'choic', 'charact', 'hunki', 'physic', 'appear', 'appropri', 'style', 'one', 'actor', 'career', 'peak', 'perform', 'edward', 'norton', 'prove', 'qualifi', 'product', 'like', 'american', 'histori', 'x', 'rather', 'lightheart', 'romant', 'comedi', 'like', 'keep',  ...
#
# Step 6: Result after Lemmatization is:
# ['FIGHT', 'CLUB', 'Viewing', 'Fight', 'Club', 'new', 'drama', 'assertive', 'director', 'David', 'Fincher', 'like', 'walking', 'graffitiladen', 'street', 'crimeridden', 'suburban', 'city', 'dark', 'brutal', 'gritty', 'troublesome', 'hostile', 'This', 'film', 'thing', 'circumstance', 'I', 'use', 'adjective', 'production', 'credit', 'Fight', 'Club', 'coarse', 'unpleasing', 'journey', 'life', 'narcotic', 'character', 'exact', 'reason', 'I', 'find', 'recommending', 'movie', 'audience', 'strong', 'stomach', 'If', 'film', 'anything', 'I', 'already', 'described', 'would', 'appalled', 'deserving', 'controversy', 'violent', 'content', 'contained', 'The', 'hostility', 'Fight', 'Club', 'main', 'factor', 'succeeds', 'raucous', 'style', 'contributes', 'making', 'convincing', 'entertaining', 'recklessly', 'original', 'storyEdward', 'Norton', 'star', 'movie', 'narrator', 'insomniac', 'spending', 'petty', 'day', 'working', 'office', 'sleepless', 'night', 'seeking', 'clinic', 'provides', 'comfort', 'le', 'fortunate', 'One', 'people', 'meet', 'overweight', 'gentle', 'pedestrian', 'named', 'Robert', 'Paulson', 'Meat', 'Loaf', 'victim', 'testicular', 'cancer', 'He', 'also', 'meet', 'sleazy', 'foulmouthed', 'drifter', 'like', 'named', 'Marla', 'Singer', 'Helena', 'Bonham', 'CarterNortons', 'character', 'development', 'quite', 'unusual', 'although', 'effective', 'versatile', 'introduction', 'rest', 'movie', 'extremely', 'bleak', 'It', 'character', 'creating', 'antisociety', 'story', 'perverse', 'behavior', 'We', 'witness', 'movie', 'Narrators', 'point', 'view', 'end', 'explaining', 'plot', 'necessaryDuring', 'plane', 'flight', 'undervalued', 'narrator', 'encounter', 'cocky', 'welldressed', 'soap', 'sale', 'representative', 'named', 'Tyler', 'Durden', 'Brat', 'Pit', 'whose', 'sarcastic', 'outspoken', 'notion', 'create', 'charisma', 'individual', 'Shortly', 'afterwards', 'Narrators', 'apartment', 'blow', 'apart', 'leaving', 'nowhere', 'seek', 'shelter', 'Tyler', 'This', 'enigmatic', 'man', 'organizes', 'underground', 'sensation', 'called', 'Fight', 'Club', 'young', 'men', 'inquire', 'pleasure', 'beating', 'bloody', 'carnage', 'This', 'secret', 'society', 'located', 'basement', 'local', 'bar', 'allows', 'member', 'find', 'selfdiscovery', 'freedom', 'brawl', 'scufflesFight', 'Club', 'crafted', 'stirringly', 'structured', 'innovation', 'production', 'design', 'Art', 'director', 'Chris', 'Gorak', 'production', 'designer', 'Alex', 'McDowell', 'cinematographer', 'Jeff', 'Cornenweth', 'capture', 'film', 'subversive', 'atmosphere', 'vivid', 'detail', 'descriptive', 'style', 'dazzling', 'lighting', 'technique', 'Costume', 'design', 'Michael', 'Kaplan', 'contribute', 'development', 'Tyler', 'Durden', 'distinctive', 'creative', 'outfitsDavid', 'Fincher', 'currently', 'one', 'favorite', 'director', 'His', 'striking', 'suspenseful', 'thriller', 'The', 'Game', 'Seven', 'captured', 'attention', 'thoroughly', 'sharp', 'character', 'focused', 'narrative', 'The', 'Game', 'detailed', 'wealthy', 'executive', 'immersed', 'confederacy', 'must', 'overcome', 'variety', 'challenge', 'survive', 'Fight', 'Club', 'le', 'topic', 'rebellious', 'benefactor', 'assist', 'taking', 'charge', 'lack', 'freedom', 'violent', 'encounter', 'This', 'production', 'contains', 'plot', 'twist', 'climatic', 'resolution', 'may', 'require', 'reasoning', 'thought', 'majority', 'audience', 'willing', 'submitFight', 'Club', 'contains', 'enough', 'extreme', 'graphic', 'violent', 'content', 'several', 'movie', 'yet', 'character', 'end', 'severe', 'injury', 'When', 'tough', 'young', 'man', 'beat', 'someone', 'face', 'ground', 'resulting', 'much', 'gore', 'hardly', 'recognizable', 'would', 'expect', 'person', 'end', 'critical', 'condition', 'hospital', 'However', 'many', 'character', 'movie', 'engage', 'uncultivated', 'attack', 'appear', 'modest', 'condition', 'following', 'day', 'I', 'guess', 'movie', 'center', 'theme', 'character', 'actual', 'course', 'action', 'obligatory', 'successBrad', 'Pitt', 'captu ...
#
# Original Text:
# Fight Club' is a superb filmmaking achievement.  It is brutal, innovative, raw, realistic, and extremely powerful.  You could not ask more from the actors.  Edward Norton once again portrays a psyche in delicate imbalance with potent and believable intensity.  Brad Pitt moves to the far side of diabolical and excels in making his character both warped and charismatic. Helena Bonham Carter also shines as the Tyler's pathetic and parasitic girl friend.Fight Club' takes some of the most pernicious elements of societal dysfunction and wraps them up into a single imaginative well crafted and entertaining film.  We have elements of gang behavior, cultism, anarchy, terrorism and debauchery all glorified in the name of iconoclasm.  Exciting, seductive and subversive.  How utterly cool and hip!So now comes the twist.  I hated this film.  It is a monument to everything that is wrong with filmmaking today.  It is clever and technically superb but philosophically and socially bereft.  Its attempt at social satire, while effective and visceral, was destructive and noxious.  I also can't help but notice the extreme irony of using satire against consumerism as the theme for inducing the masses to buy tickets to consume your film.At what point does a film cross the line between art and depravity?  Fight Club' is a brilliant but dangerous film that begs the question.  If art is a reflection of a society's culture and values, then when I look at this film I have to be frightened at what is staring back at me.  When I reflect on some of the most popular films of the last five years, I can't help but notice the accelerating celebration of random and impulsive violence, depravity, decadence, and pure bad taste.  Fight Club' has pushed the envelope once again to find a new pinnacle (or should I say nadir) in the portrayal of these corrosive elements of societal dissolution.It's comical how many people think it is avant-guard to attack the establishment, as if this is a concept only recently conceived.  Fight Club' is just the latest rallying cry to anarchy in a long line of such cries that have plagued society throughout human history.  It always seems to be a romantic notion for everyone to be totally free and just live `naturally' (like animals) until one of those animals decides that it is you whom it might be fun to kill today.  It doesn't seem to occur to those who extol the sardonic message of such films, that they simultaneously promote and lionize societal destabilization, and that anarchy and mayhem are much less fun in real life than when you are watching them in the air conditioned comfort of your local movie house.  Just ask the kids at Columbine High School.I like dark movies as much or more than the next guy, but this film simply goes too far.  There is nothing wrong with criticizing the establishment. Constructive criticism is the only way to bring about progressive change. But this film is merely vulgar cynicism that suggests that mayhem is preferable to imperfect culture.  That is grossly irresponsible.So I am placed in the paradoxical position of admiring this film while I must condemn it.  As a flickjunkie I must stand in awe of it as a filmmaking accomplishment.  But as a human being concerned with the greater good of the species, I must cry out against it.  How far are we willing to go in the name of entertainment?  Are we so myopic as to demand entertainment at any cost?  I guess we will see when someone raises the ante and the next shock treatment comes to a theater near you.
#
# Step 1: Result after removing special characters and punctuation is:
# Fight Club is a superb filmmaking achievement  It is brutal innovative raw realistic and extremely powerful  You could not ask more from the actors  Edward Norton once again portrays a psyche in delicate imbalance with potent and believable intensity  Brad Pitt moves to the far side of diabolical and excels in making his character both warped and charismatic Helena Bonham Carter also shines as the Tylers pathetic and parasitic girl friendFight Club takes some of the most pernicious elements of societal dysfunction and wraps them up into a single imaginative well crafted and entertaining film  We have elements of gang behavior cultism anarchy terrorism and debauchery all glorified in the name of iconoclasm  Exciting seductive and subversive  How utterly cool and hipSo now comes the twist  I hated this film  It is a monument to everything that is wrong with filmmaking today  It is clever and technically superb but philosophically and socially bereft  Its attempt at social satire while effective and visceral was destructive and noxious  I also cant help but notice the extreme irony of using satire against consumerism as the theme for inducing the masses to buy tickets to consume your filmAt what point does a film cross the line between art and depravity  Fight Club is a brilliant but dangerous film that begs the question  If art is a reflection of a societys culture and values then when I look at this film I have to be frightened at what is staring back at me  When I reflect on some of the most popular films of the last five years I cant help but notice the accelerating celebration of random and impulsive violence depravity decadence and pure bad taste  Fight Club has pushed the envelope once again to find a new pinnacle or should I say nadir in the portrayal of these corrosive elements of societal dissolutionIts comical how many people think it is avantguard to attack the establishment as if this is a concept only recently conceived  Fight Club is just the latest rallying cry to anarchy in a long line of such cries that have plagued society throughout human history  It always seems to be a romantic notion for everyone to be totally free and just live naturally like animals until one of those animals decides that it is you whom it might be fun to kill today  It doesnt seem to occur to those who extol the sardonic message of such films that they simultaneously promote and lionize societal destabilization and that anarchy and mayhem are much less fun in real life than when you are watching them in the air conditioned comfort of your local movie house  Just ask the kids at Columbine High SchoolI like dark movies as much or more than the next guy but this film simply goes too far  There is nothing wrong with criticizing the establishment Constructive criticism is the only way to bring about progressive change But this film is merely vulgar cynicism that suggests that mayhem is preferable to imperfect culture  That is grossly irresponsibleSo I am placed in the paradoxical position of admiring this film while I must condemn it  As a flickjunkie I must stand in awe of it as a filmmaking accomplishment  But as a human being concerned with the greater good of the species I must cry out against it  How far are we willing to go in the name of entertainment  Are we so myopic as to demand entertainment at any cost  I guess we will see when someone raises the ante and the next shock treatment comes to a theater near you
#
# Step 2: Result after removing numbers in the text is:
# Fight Club is a superb filmmaking achievement  It is brutal innovative raw realistic and extremely powerful  You could not ask more from the actors  Edward Norton once again portrays a psyche in delicate imbalance with potent and believable intensity  Brad Pitt moves to the far side of diabolical and excels in making his character both warped and charismatic Helena Bonham Carter also shines as the Tylers pathetic and parasitic girl friendFight Club takes some of the most pernicious elements of societal dysfunction and wraps them up into a single imaginative well crafted and entertaining film  We have elements of gang behavior cultism anarchy terrorism and debauchery all glorified in the name of iconoclasm  Exciting seductive and subversive  How utterly cool and hipSo now comes the twist  I hated this film  It is a monument to everything that is wrong with filmmaking today  It is clever and technically superb but philosophically and socially bereft  Its attempt at social satire while effective and visceral was destructive and noxious  I also cant help but notice the extreme irony of using satire against consumerism as the theme for inducing the masses to buy tickets to consume your filmAt what point does a film cross the line between art and depravity  Fight Club is a brilliant but dangerous film that begs the question  If art is a reflection of a societys culture and values then when I look at this film I have to be frightened at what is staring back at me  When I reflect on some of the most popular films of the last five years I cant help but notice the accelerating celebration of random and impulsive violence depravity decadence and pure bad taste  Fight Club has pushed the envelope once again to find a new pinnacle or should I say nadir in the portrayal of these corrosive elements of societal dissolutionIts comical how many people think it is avantguard to attack the establishment as if this is a concept only recently conceived  Fight Club is just the latest rallying cry to anarchy in a long line of such cries that have plagued society throughout human history  It always seems to be a romantic notion for everyone to be totally free and just live naturally like animals until one of those animals decides that it is you whom it might be fun to kill today  It doesnt seem to occur to those who extol the sardonic message of such films that they simultaneously promote and lionize societal destabilization and that anarchy and mayhem are much less fun in real life than when you are watching them in the air conditioned comfort of your local movie house  Just ask the kids at Columbine High SchoolI like dark movies as much or more than the next guy but this film simply goes too far  There is nothing wrong with criticizing the establishment Constructive criticism is the only way to bring about progressive change But this film is merely vulgar cynicism that suggests that mayhem is preferable to imperfect culture  That is grossly irresponsibleSo I am placed in the paradoxical position of admiring this film while I must condemn it  As a flickjunkie I must stand in awe of it as a filmmaking accomplishment  But as a human being concerned with the greater good of the species I must cry out against it  How far are we willing to go in the name of entertainment  Are we so myopic as to demand entertainment at any cost  I guess we will see when someone raises the ante and the next shock treatment comes to a theater near you
#
# ...
#
# Step 2: Result after removing numbers in the text is:
# A great adaptation from an eloquently written novel Two things that made this flick a crowning achievement are the screenplay and the performancesThe movie stayed faithful to the book thus the script was immensely entertaining and thought provoking Every new line and scene they added fitted the sources messaging perfectly That shows how much they understood the theme of the book A paragon Hollywood needs to strive for when adapting a bookThe crème de la crème of the actors for me was Ed Norton Ed delivered in an astounding manner His emotive performance on the hand burning scene and his beat up and tired features felt impressively authentic The intensity of his voice changing to fit the lines messaging showed he understood the core gist of the book really well That again shows his dedication for the role he was given He was just the best man for the roleHelena Bonham was also perfect for Marla as she also seemed as miserable as her book counterpart Brad Pitts charismatic and self assured performance was also admirable He went a wee bit boyish on some scenes but mostly did well so that makes up for his blundersAll the minor characters in fight club were incredibly convincing too Movie was filled with a spectacular castBesides all that I wanna praise the stylistic editing  the phenomenal ending scene and the pixies songFight club is a superb and examplary adaptation thats constantly rewatchable A gem that didnt disappoint fans of the book
#
# Step 3: Result after tokenizing and removing stopwords:
# ['A', 'great', 'adaptation', 'eloquently', 'written', 'novel', 'Two', 'things', 'made', 'flick', 'crowning', 'achievement', 'screenplay', 'performancesThe', 'movie', 'stayed', 'faithful', 'book', 'thus', 'script', 'immensely', 'entertaining', 'thought', 'provoking', 'Every', 'new', 'line', 'scene', 'added', 'fitted', 'sources', 'messaging', 'perfectly', 'That', 'shows', 'much', 'understood', 'theme', 'book', 'A', 'paragon', 'Hollywood', 'needs', 'strive', 'adapting', 'bookThe', 'crème', 'de', 'la', 'crème', 'actors', 'Ed', 'Norton', 'Ed', 'delivered', 'astounding', 'manner', 'His', 'emotive', 'performance', 'hand', 'burning', 'scene', 'beat', 'tired', 'features', 'felt', 'impressively', 'authentic', 'The', 'intensity', 'voice', 'changing', 'fit', 'lines', 'messaging', 'showed', 'understood', 'core', 'gist', 'book', 'really', 'well', 'That', 'shows', 'dedication', 'role', 'given', 'He', 'best', 'man', 'roleHelena', 'Bonham', 'also', 'perfect', 'Marla', 'also', 'seemed', 'miserable', 'book', 'counterpart', 'Brad', 'Pitts', 'charismatic', 'self', 'assured', 'performance', 'also', 'admirable', 'He', 'went', 'wee', 'bit', 'boyish', 'scenes', 'mostly', 'well', 'makes', 'blundersAll', 'minor', 'characters', 'fight', 'club', 'incredibly', 'convincing', 'Movie', 'filled', 'spectacular', 'castBesides', 'I', 'wan', 'na', 'praise', 'stylistic', 'editing', 'phenomenal', 'ending', 'scene', 'pixies', 'songFight', 'club', 'superb', 'examplary', 'adaptation', 'thats', 'constantly', 'rewatchable', 'A', 'gem', 'didnt', 'disappoint', 'fans', 'book']
#
# Step 4: LowerCase text is:
# a great adaptation from an eloquently written novel two things that made this flick a crowning achievement are the screenplay and the performancesthe movie stayed faithful to the book thus the script was immensely entertaining and thought provoking every new line and scene they added fitted the sources messaging perfectly that shows how much they understood the theme of the book a paragon hollywood needs to strive for when adapting a bookthe crème de la crème of the actors for me was ed norton ed delivered in an astounding manner his emotive performance on the hand burning scene and his beat up and tired features felt impressively authentic the intensity of his voice changing to fit the lines messaging showed he understood the core gist of the book really well that again shows his dedication for the role he was given he was just the best man for the rolehelena bonham was also perfect for marla as she also seemed as miserable as her book counterpart brad pitts charismatic and self assured performance was also admirable he went a wee bit boyish on some scenes but mostly did well so that makes up for his blundersall the minor characters in fight club were incredibly convincing too movie was filled with a spectacular castbesides all that i wanna praise the stylistic editing  the phenomenal ending scene and the pixies songfight club is a superb and examplary adaptation thats constantly rewatchable a gem that didnt disappoint fans of the book
#
# Step 5: Ouput of the text after stemming is:
# ['a', 'great', 'adapt', 'eloqu', 'written', 'novel', 'two', 'thing', 'made', 'flick', 'crown', 'achiev', 'screenplay', 'performancesth', 'movi', 'stay', 'faith', 'book', 'thu', 'script', 'immens', 'entertain', 'thought', 'provok', 'everi', 'new', 'line', 'scene', 'ad', 'fit', 'sourc', 'messag', 'perfectli', 'that', 'show', 'much', 'understood', 'theme', 'book', 'a', 'paragon', 'hollywood', 'need', 'strive', 'adapt', 'bookth', 'crème', 'de', 'la', 'crème', 'actor', 'ed', 'norton', 'ed', 'deliv', 'astound', 'manner', 'hi', 'emot', 'perform', 'hand', 'burn', 'scene', 'beat', 'tire', 'featur', 'felt', 'impress', 'authent', 'the', 'intens', 'voic', 'chang', 'fit', 'line', 'messag', 'show', 'understood', 'core', 'gist', 'book', 'realli', 'well', 'that', 'show', 'dedic', 'role', 'given', 'he', 'best', 'man', 'rolehelena', 'bonham', 'also', 'perfect', 'marla', 'also', 'seem', 'miser', 'book', 'counterpart', 'brad', 'pitt', 'charismat', 'self', 'assur', 'perform', 'also', 'admir', 'he', 'went', 'wee', 'bit', 'boyish', 'scene', 'mostli', 'well', 'make', 'blundersal', 'minor', 'charact', 'fight', 'club', 'incred', 'convinc', 'movi', 'fill', 'spectacular', 'castbesid', 'i', 'wan', 'na', 'prais', 'stylist', 'edit', 'phenomen', 'end', 'scene', 'pixi', 'songfight', 'club', 'superb', 'examplari', 'adapt', 'that', 'constantli', 'rewatch', 'a', 'gem', 'didnt', 'disappoint', 'fan', 'book']
#
# Step 6: Result after Lemmatization is:
# ['A', 'great', 'adaptation', 'eloquently', 'written', 'novel', 'Two', 'thing', 'made', 'flick', 'crowning', 'achievement', 'screenplay', 'performancesThe', 'movie', 'stayed', 'faithful', 'book', 'thus', 'script', 'immensely', 'entertaining', 'thought', 'provoking', 'Every', 'new', 'line', 'scene', 'added', 'fitted', 'source', 'messaging', 'perfectly', 'That', 'show', 'much', 'understood', 'theme', 'book', 'A', 'paragon', 'Hollywood', 'need', 'strive', 'adapting', 'bookThe', 'crème', 'de', 'la', 'crème', 'actor', 'Ed', 'Norton', 'Ed', 'delivered', 'astounding', 'manner', 'His', 'emotive', 'performance', 'hand', 'burning', 'scene', 'beat', 'tired', 'feature', 'felt', 'impressively', 'authentic', 'The', 'intensity', 'voice', 'changing', 'fit', 'line', 'messaging', 'showed', 'understood', 'core', 'gist', 'book', 'really', 'well', 'That', 'show', 'dedication', 'role', 'given', 'He', 'best', 'man', 'roleHelena', 'Bonham', 'also', 'perfect', 'Marla', 'also', 'seemed', 'miserable', 'book', 'counterpart', 'Brad', 'Pitts', 'charismatic', 'self', 'assured', 'performance', 'also', 'admirable', 'He', 'went', 'wee', 'bit', 'boyish', 'scene', 'mostly', 'well', 'make', 'blundersAll', 'minor', 'character', 'fight', 'club', 'incredibly', 'convincing', 'Movie', 'filled', 'spectacular', 'castBesides', 'I', 'wan', 'na', 'praise', 'stylistic', 'editing', 'phenomenal', 'ending', 'scene', 'pixy', 'songFight', 'club', 'superb', 'examplary', 'adaptation', 'thats', 'constantly', 'rewatchable', 'A', 'gem', 'didnt', 'disappoint', 'fan', 'book']
#
# Original Text:
# These type of movie comes in decades with outstanding actor brad pitt
#
# Step 1: Result after removing special characters and punctuation is:
# These type of movie comes in decades with outstanding actor brad pitt
#
# Step 2: Result after removing numbers in the text is:
# These type of movie comes in decades with outstanding actor brad pitt
#
# Step 3: Result after tokenizing and removing stopwords:
# ['These', 'type', 'movie', 'comes', 'decades', 'outstanding', 'actor', 'brad', 'pitt']
#
# Step 4: LowerCase text is:
# these type of movie comes in decades with outstanding actor brad pitt
#
# Step 5: Ouput of the text after stemming is:
# ['these', 'type', 'movi', 'come', 'decad', 'outstand', 'actor', 'brad', 'pitt']
#
# Step 6: Result after Lemmatization is:
# ['These', 'type', 'movie', 'come', 'decade', 'outstanding', 'actor', 'brad', 'pitt']
#
# Original Text:
# A film to make you rethink your life. And reconsider the clubs you patronise. Norton, Pitt, Bohnam-Carter have never been so annihilating... a cult classic for sure.
#
# Step 1: Result after removing special characters and punctuation is:
# A film to make you rethink your life And reconsider the clubs you patronise Norton Pitt BohnamCarter have never been so annihilating a cult classic for sure
#
# Step 2: Result after removing numbers in the text is:
# A film to make you rethink your life And reconsider the clubs you patronise Norton Pitt BohnamCarter have never been so annihilating a cult classic for sure
#
# Step 3: Result after tokenizing and removing stopwords:
# ['A', 'film', 'make', 'rethink', 'life', 'And', 'reconsider', 'clubs', 'patronise', 'Norton', 'Pitt', 'BohnamCarter', 'never', 'annihilating', 'cult', 'classic', 'sure']
#
# Step 4: LowerCase text is:
# a film to make you rethink your life and reconsider the clubs you patronise norton pitt bohnamcarter have never been so annihilating a cult classic for sure
#
# Step 5: Ouput of the text after stemming is:
# ['a', 'film', 'make', 'rethink', 'life', 'and', 'reconsid', 'club', 'patronis', 'norton', 'pitt', 'bohnamcart', 'never', 'annihil', 'cult', 'classic', 'sure']
#
# Step 6: Result after Lemmatization is:
# ['A', 'film', 'make', 'rethink', 'life', 'And', 'reconsider', 'club', 'patronise', 'Norton', 'Pitt', 'BohnamCarter', 'never', 'annihilating', 'cult', 'classic', 'sure']
#
# Original Text:
# I am 34, I have seen thousands of films, and this is unquestionably the absolute worst. It is evil. Technically well done, but evil still. This film shits on every value I hold dear : honesty, hard work, liberty of thought, non-violence, respect of others as equals, reason as my best tool to make something of my life. It glorifies senseless destruction of property and (which is much, much worse) of able minds in cult-like brainwashing to serve egoistical means. Every problem should be overcome with violence, lies, or blackmail. Every man who is not you is there to be used or beaten into a pathetic degenerate. There is no respect of the other. Also, the "plot twist" had me wincing. It was so very obvious from the start that when it happened, I just sighed and shook my head.
#
# Step 1: Result after removing special characters and punctuation is:
# I am 34 I have seen thousands of films and this is unquestionably the absolute worst It is evil Technically well done but evil still This film shits on every value I hold dear  honesty hard work liberty of thought nonviolence respect of others as equals reason as my best tool to make something of my life It glorifies senseless destruction of property and which is much much worse of able minds in cultlike brainwashing to serve egoistical means Every problem should be overcome with violence lies or blackmail Every man who is not you is there to be used or beaten into a pathetic degenerate There is no respect of the other Also the plot twist had me wincing It was so very obvious from the start that when it happened I just sighed and shook my head
#
# Step 2: Result after removing numbers in the text is:
# I am  I have seen thousands of films and this is unquestionably the absolute worst It is evil Technically well done but evil still This film shits on every value I hold dear  honesty hard work liberty of thought nonviolence respect of others as equals reason as my best tool to make something of my life It glorifies senseless destruction of property and which is much much worse of able minds in cultlike brainwashing to serve egoistical means Every problem should be overcome with violence lies or blackmail Every man who is not you is there to be used or beaten into a pathetic degenerate There is no respect of the other Also the plot twist had me wincing It was so very obvious from the start that when it happened I just sighed and shook my head
#
# Step 3: Result after tokenizing and removing stopwords:
# ['I', 'I', 'seen', 'thousands', 'films', 'unquestionably', 'absolute', 'worst', 'It', 'evil', 'Technically', 'well', 'done', 'evil', 'still', 'This', 'film', 'shits', 'every', 'value', 'I', 'hold', 'dear', 'honesty', 'hard', 'work', 'liberty', 'thought', 'nonviolence', 'respect', 'others', 'equals', 'reason', 'best', 'tool', 'make', 'something', 'life', 'It', 'glorifies', 'senseless', 'destruction', 'property', 'much', 'much', 'worse', 'able', 'minds', 'cultlike', 'brainwashing', 'serve', 'egoistical', 'means', 'Every', 'problem', 'overcome', 'violence', 'lies', 'blackmail', 'Every', 'man', 'used', 'beaten', 'pathetic', 'degenerate', 'There', 'respect', 'Also', 'plot', 'twist', 'wincing', 'It', 'obvious', 'start', 'happened', 'I', 'sighed', 'shook', 'head']
#
# Step 4: LowerCase text is:
# i am  i have seen thousands of films and this is unquestionably the absolute worst it is evil technically well done but evil still this film shits on every value i hold dear  honesty hard work liberty of thought nonviolence respect of others as equals reason as my best tool to make something of my life it glorifies senseless destruction of property and which is much much worse of able minds in cultlike brainwashing to serve egoistical means every problem should be overcome with violence lies or blackmail every man who is not you is there to be used or beaten into a pathetic degenerate there is no respect of the other also the plot twist had me wincing it was so very obvious from the start that when it happened i just sighed and shook my head
#
# Step 5: Ouput of the text after stemming is:
# ['i', 'i', 'seen', 'thousand', 'film', 'unquestion', 'absolut', 'worst', 'it', 'evil', 'technic', 'well', 'done', 'evil', 'still', 'thi', 'film', 'shit', 'everi', 'valu', 'i', 'hold', 'dear', 'honesti', 'hard', 'work', 'liberti', 'thought', 'nonviol', 'respect', 'other', 'equal', 'reason', 'best', 'tool', 'make', 'someth', 'life', 'it', 'glorifi', 'senseless', 'destruct', 'properti', 'much', 'much', 'wors', 'abl', 'mind', 'cultlik', 'brainwash', 'serv', 'egoist', 'mean', 'everi', 'problem', 'overcom', 'violenc', 'lie', 'blackmail', 'everi', 'man', 'use', 'beaten', 'pathet', 'degener', 'there', 'respect', 'also', 'plot', 'twist', 'winc', 'it', 'obviou', 'start', 'happen', 'i', 'sigh', 'shook', 'head']
#
# Step 6: Result after Lemmatization is:
# ['I', 'I', 'seen', 'thousand', 'film', 'unquestionably', 'absolute', 'worst', 'It', 'evil', 'Technically', 'well', 'done', 'evil', 'still', 'This', 'film', 'shit', 'every', 'value', 'I', 'hold', 'dear', 'honesty', 'hard', 'work', 'liberty', 'thought', 'nonviolence', 'respect', 'others', 'equal', 'reason', 'best', 'tool', 'make', 'something', 'life', 'It', 'glorifies', 'senseless', 'destruction', 'property', 'much', 'much', 'worse', 'able', 'mind', 'cultlike', 'brainwashing', 'serve', 'egoistical', 'mean', 'Every', 'problem', 'overcome', 'violence', 'lie', 'blackmail', 'Every', 'man', 'used', 'beaten', 'pathetic', 'degenerate', 'There', 'respect', 'Also', 'plot', 'twist', 'wincing', 'It', 'obvious', 'start', 'happened', 'I', 'sighed', 'shook', 'head']
#
# Cleaned data saved to 1000_reviews_cleaned.csv

# %% [markdown]
# # Question 3 (30 points)
#
# Write a python program to **conduct syntax and structure analysis of the clean text** you just saved above. The syntax and structure analysis includes:
#
# (1) **Parts of Speech (POS) Tagging:** Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) **Constituency Parsing and Dependency Parsing:** print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) **Named Entity Recognition:** Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
import pandas as pd
import nltk
from collections import Counter

# Download NLTK resources
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('treebank')

# Read cleaned text
df = pd.read_csv('1000_reviews_cleaned.csv')

# Function for POS tagging and counting
def pos_tag_and_count(text):
    tokens = nltk.word_tokenize(text)
    pos_tags = nltk.pos_tag(tokens)
    pos_counts = Counter(tag for word, tag in pos_tags)
    return pos_counts

# Function for Named Entity Recognition (NER) and counting
def ner_and_count(text):
    tokens = nltk.word_tokenize(text)
    pos_tags = nltk.pos_tag(tokens)
    ner_tags = nltk.ne_chunk(pos_tags)
    ner_counts = Counter(chunk.label() for chunk in ner_tags if hasattr(chunk, 'label'))
    return ner_counts

# Apply functions to each review
for index, row in df.iterrows():
    print(f"Named Entity Recognition for Review {index + 1}:")
    ner_counts = ner_and_count(row['Cleaned_Review'])
    print(ner_counts)
    print("-" * 50)

    print(f"POS Tagging for Review {index + 1}:")
    pos_counts = pos_tag_and_count(row['Cleaned_Review'])
    print(pos_counts)
    print("-" * 50)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Unzipping corpora/treebank.zip.
# Streaming output truncated to the last 5000 lines.
# Counter({'NN': 46, 'JJ': 21, 'RB': 12, 'NNP': 9, 'DT': 5, 'VBN': 3, 'CD': 3, 'VBP': 3, 'PRP': 3, 'VBZ': 3, 'VBD': 3, 'VBG': 2, 'IN': 2, 'VB': 2, 'PRP$': 1, 'EX': 1, 'CC': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 185:
# Counter({'ORGANIZATION': 3, 'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 185:
# Counter({'NN': 44, 'JJ': 27, 'VBG': 7, 'VBP': 7, 'RB': 6, 'NNP': 5, 'DT': 4, 'IN': 4, 'VB': 4, 'PRP': 3, 'VBD': 3, 'JJS': 3, 'VBN': 3, 'MD': 2, 'VBZ': 1, 'RBR': 1, 'UH': 1, 'NNS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 186:
# Counter({'GSP': 1, 'ORGANIZATION': 1})
# --------------------------------------------------
# POS Tagging for Review 186:
# Counter({'NN': 29, 'JJ': 15, 'VBD': 7, 'RB': 6, 'NNP': 3, 'EX': 1, 'VBZ': 1, 'NNS': 1, 'VBG': 1, 'MD': 1, 'VB': 1, 'IN': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 187:
# Counter({'ORGANIZATION': 9, 'PERSON': 6, 'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 187:
# Counter({'NN': 65, 'JJ': 40, 'RB': 23, 'NNP': 21, 'VBP': 15, 'VBD': 9, 'VBG': 8, 'CD': 6, 'DT': 6, 'VB': 5, 'VBZ': 4, 'CC': 4, 'VBN': 3, 'NNS': 3, 'PRP': 3, 'MD': 3, 'IN': 2, 'EX': 2, 'WP': 2, 'PRP$': 2, 'UH': 1, 'RP': 1, 'JJS': 1, 'WP$': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 188:
# Counter()
# --------------------------------------------------
# POS Tagging for Review 188:
# Counter({'NN': 12, 'PRP': 7, 'VBP': 7, 'JJ': 6, 'RB': 5, 'VBG': 2, 'MD': 1, 'NNS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 189:
# Counter({'PERSON': 3})
# --------------------------------------------------
# POS Tagging for Review 189:
# Counter({'NN': 21, 'JJ': 18, 'RB': 12, 'NNP': 9, 'VBD': 6, 'VBP': 5, 'PRP': 4, 'IN': 4, 'VBG': 2, 'CC': 1, 'JJS': 1, 'VBN': 1, 'DT': 1, 'NNS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 190:
# Counter({'PERSON': 6})
# --------------------------------------------------
# POS Tagging for Review 190:
# Counter({'NN': 31, 'JJ': 14, 'NNP': 14, 'VBG': 8, 'RB': 6, 'VBD': 4, 'IN': 3, 'NNS': 2, 'JJR': 2, 'VBP': 2, 'PRP': 2, 'VBZ': 1, 'PRP$': 1, 'CC': 1, 'DT': 1, 'CD': 1, 'VB': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 191:
# Counter({'ORGANIZATION': 3})
# --------------------------------------------------
# POS Tagging for Review 191:
# Counter({'NN': 31, 'JJ': 10, 'RB': 7, 'VBP': 6, 'PRP': 4, 'VBG': 4, 'DT': 3, 'IN': 2, 'VB': 2, 'VBD': 2, 'NNS': 2, 'VBN': 2, 'NNP': 1, 'JJR': 1, 'CC': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 192:
# Counter({'PERSON': 6, 'ORGANIZATION': 2})
# --------------------------------------------------
# POS Tagging for Review 192:
# Counter({'NN': 56, 'RB': 31, 'JJ': 27, 'NNP': 21, 'PRP': 15, 'VBP': 14, 'VBG': 10, 'IN': 8, 'VBN': 6, 'VBD': 6, 'VB': 6, 'CC': 3, 'NNS': 3, 'MD': 3, 'CD': 2, 'JJS': 2, 'DT': 2, 'VBZ': 2, 'JJR': 2, 'RP': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 193:
# Counter({'PERSON': 2, 'ORGANIZATION': 1})
# --------------------------------------------------
# POS Tagging for Review 193:
# Counter({'NN': 39, 'JJ': 23, 'RB': 13, 'VBG': 8, 'NNP': 7, 'VBP': 7, 'CD': 6, 'VBD': 4, 'PRP': 4, 'JJR': 3, 'VBZ': 2, 'PRP$': 2, 'VB': 2, 'WP': 1, 'VBN': 1, 'IN': 1, 'DT': 1, 'JJS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 194:
# Counter({'ORGANIZATION': 2, 'PERSON': 1})
# --------------------------------------------------
# POS Tagging for Review 194:
# Counter({'NN': 4, 'NNP': 3, 'RB': 3, 'VBD': 1, 'NNS': 1, 'VBP': 1, 'DT': 1, 'PRP': 1, 'VBN': 1, 'JJ': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 195:
# Counter({'PERSON': 31, 'ORGANIZATION': 5, 'GPE': 2})
# --------------------------------------------------
# POS Tagging for Review 195:
# Counter({'NN': 124, 'NNP': 87, 'JJ': 63, 'RB': 48, 'VBG': 22, 'VBD': 15, 'NNS': 14, 'VBP': 12, 'VBZ': 10, 'IN': 10, 'VB': 8, 'VBN': 5, 'PRP$': 4, 'DT': 4, 'WP': 3, 'CD': 3, 'PRP': 2, 'JJR': 2, 'TO': 1, 'JJS': 1, 'NNPS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 196:
# Counter()
# --------------------------------------------------
# POS Tagging for Review 196:
# Counter({'NN': 10, 'JJ': 6, 'VBG': 5, 'RB': 4, 'VBD': 3, 'PRP': 3, 'PRP$': 2, 'VBP': 1, 'RBR': 1, 'VB': 1, 'NNS': 1, 'WP$': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 197:
# Counter()
# --------------------------------------------------
# POS Tagging for Review 197:
# Counter({'NN': 4, 'DT': 1, 'RB': 1, 'JJ': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 198:
# Counter()
# --------------------------------------------------
# POS Tagging for Review 198:
# Counter({'NN': 12, 'JJ': 12, 'RB': 8, 'DT': 2, 'VBG': 2, 'VBP': 1, 'VB': 1, 'NNP': 1, 'VBD': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 199:
# Counter({'PERSON': 2, 'GPE': 1, 'ORGANIZATION': 1})
# --------------------------------------------------
# POS Tagging for Review 199:
# Counter({'NN': 21, 'JJ': 8, 'RB': 7, 'VBP': 7, 'NNS': 7, 'NNP': 6, 'IN': 6, 'VBN': 3, 'DT': 2, 'VBG': 1, 'VB': 1, 'VBD': 1, 'JJS': 1, 'RBR': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 200:
# Counter({'ORGANIZATION': 4, 'PERSON': 1})
# --------------------------------------------------
# POS Tagging for Review 200:
# Counter({'NN': 24, 'JJ': 12, 'NNP': 11, 'RB': 6, 'VBG': 5, 'VB': 4, 'DT': 4, 'VBN': 3, 'VBP': 3, 'CD': 2, 'VBZ': 2, 'PRP$': 1, 'IN': 1, 'WRB': 1, 'MD': 1, 'EX': 1, 'RBR': 1, 'PRP': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 201:
# Counter({'PERSON': 1})
# --------------------------------------------------
# POS Tagging for Review 201:
# Counter({'NN': 8, 'JJ': 4, 'RB': 2, 'NNP': 2, 'WP': 1, 'VBG': 1, 'VBD': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 202:
# Counter({'ORGANIZATION': 5, 'PERSON': 1})
# --------------------------------------------------
# POS Tagging for Review 202:
# Counter({'NN': 52, 'JJ': 24, 'RB': 12, 'VBP': 9, 'VBG': 6, 'NNP': 6, 'PRP': 4, 'IN': 4, 'VBZ': 3, 'VB': 3, 'DT': 2, 'VBD': 2, 'JJR': 2, 'MD': 2, 'VBN': 2, 'NNS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 203:
# Counter({'PERSON': 27, 'ORGANIZATION': 9, 'GPE': 8})
# --------------------------------------------------
# POS Tagging for Review 203:
# Counter({'NN': 153, 'NNP': 87, 'JJ': 66, 'RB': 39, 'VBG': 25, 'VBP': 22, 'VBN': 16, 'VBD': 16, 'VBZ': 12, 'PRP': 10, 'IN': 9, 'DT': 9, 'NNS': 8, 'CD': 7, 'VB': 7, 'CC': 6, 'FW': 2, 'RBR': 2, 'MD': 2, 'WP': 2, 'JJS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 204:
# Counter()
# --------------------------------------------------
# POS Tagging for Review 204:
# Counter({'NN': 12, 'JJ': 5, 'PRP': 3, 'VBP': 3, 'RB': 3, 'VBG': 3, 'VBD': 2, 'MD': 2, 'VB': 2, 'IN': 1, 'JJR': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 205:
# Counter({'PERSON': 40, 'GPE': 16, 'ORGANIZATION': 8})
# --------------------------------------------------
# POS Tagging for Review 205:
# Counter({'NN': 284, 'RB': 135, 'JJ': 127, 'NNP': 121, 'VBD': 45, 'PRP': 43, 'VBP': 42, 'IN': 33, 'VB': 32, 'VBG': 27, 'VBN': 18, 'CD': 17, 'DT': 14, 'MD': 12, 'NNS': 11, 'VBZ': 8, 'RBR': 5, 'JJS': 4, 'PRP$': 3, 'CC': 2, 'TO': 1, 'JJR': 1, 'WDT': 1, 'RP': 1, 'EX': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 206:
# Counter({'PERSON': 27, 'ORGANIZATION': 4, 'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 206:
# Counter({'NN': 139, 'NNP': 79, 'JJ': 69, 'RB': 27, 'VBD': 21, 'VBP': 16, 'PRP': 16, 'VBG': 14, 'VBN': 14, 'VB': 12, 'DT': 11, 'NNS': 7, 'IN': 5, 'JJS': 5, 'PRP$': 5, 'VBZ': 5, 'MD': 4, 'CD': 3, 'EX': 3, 'CC': 2, 'WRB': 1, 'RP': 1, 'RBS': 1, 'PDT': 1, 'WP$': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 207:
# Counter({'PERSON': 1})
# --------------------------------------------------
# POS Tagging for Review 207:
# Counter({'NN': 15, 'RB': 7, 'JJ': 5, 'NNP': 3, 'VBP': 3, 'DT': 2, 'PRP': 2, 'VBN': 2, 'VBZ': 1, 'MD': 1, 'VB': 1, 'WP': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 208:
# Counter({'PERSON': 7, 'ORGANIZATION': 4})
# --------------------------------------------------
# POS Tagging for Review 208:
# Counter({'NN': 97, 'JJ': 53, 'NNP': 30, 'RB': 26, 'VBG': 20, 'VBD': 13, 'VB': 8, 'PRP': 5, 'VBP': 5, 'DT': 5, 'NNS': 4, 'VBZ': 4, 'IN': 3, 'CD': 3, 'VBN': 2, 'EX': 2, 'PRP$': 1, 'JJR': 1, 'NNPS': 1, 'MD': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 209:
# Counter({'PERSON': 3, 'ORGANIZATION': 2, 'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 209:
# Counter({'NNP': 15, 'NN': 11, 'JJ': 8, 'VBP': 4, 'RB': 3, 'PRP': 3, 'VBG': 3, 'VBN': 3, 'NNS': 2, 'VBD': 1, 'RBR': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 210:
# Counter({'PERSON': 9, 'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 210:
# Counter({'NN': 91, 'JJ': 44, 'NNP': 23, 'RB': 17, 'VB': 14, 'IN': 11, 'VBG': 11, 'VBP': 9, 'VBZ': 6, 'DT': 5, 'VBD': 5, 'PRP': 4, 'MD': 4, 'EX': 2, 'NNS': 2, 'VBN': 1, 'CD': 1, 'JJS': 1, 'RP': 1, 'CC': 1, 'RBR': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 211:
# Counter({'ORGANIZATION': 4, 'PERSON': 3})
# --------------------------------------------------
# POS Tagging for Review 211:
# Counter({'NN': 24, 'JJ': 17, 'NNP': 14, 'RB': 8, 'VBP': 4, 'VBG': 3, 'VBD': 3, 'PRP': 2, 'IN': 2, 'NNS': 1, 'JJR': 1, 'VBZ': 1, 'CD': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 212:
# Counter({'PERSON': 6, 'ORGANIZATION': 5})
# --------------------------------------------------
# POS Tagging for Review 212:
# Counter({'NN': 58, 'JJ': 28, 'NNP': 18, 'VBG': 8, 'DT': 5, 'RB': 4, 'VBZ': 4, 'VBP': 3, 'VBD': 2, 'IN': 2, 'VBN': 1, 'NNS': 1, 'VB': 1, 'JJR': 1, 'NNPS': 1, 'PRP': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 213:
# Counter({'ORGANIZATION': 9, 'PERSON': 3})
# --------------------------------------------------
# POS Tagging for Review 213:
# Counter({'NN': 42, 'JJ': 20, 'NNP': 19, 'VBP': 7, 'DT': 5, 'VBG': 5, 'RB': 3, 'VBZ': 3, 'VBD': 3, 'NNS': 3, 'RBR': 2, 'PRP': 2, 'WP': 1, 'JJS': 1, 'IN': 1, 'CD': 1, 'EX': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 214:
# Counter({'PERSON': 5, 'ORGANIZATION': 3})
# --------------------------------------------------
# POS Tagging for Review 214:
# Counter({'NN': 31, 'NNP': 14, 'JJ': 14, 'RB': 4, 'VB': 3, 'VBG': 3, 'NNS': 2, 'VBD': 2, 'VBZ': 2, 'VBP': 1, 'IN': 1, 'CC': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 215:
# Counter({'ORGANIZATION': 3, 'PERSON': 2})
# --------------------------------------------------
# POS Tagging for Review 215:
# Counter({'NN': 22, 'JJ': 11, 'NNP': 9, 'RB': 6, 'VBG': 3, 'IN': 3, 'VBD': 3, 'PRP': 3, 'VBN': 2, 'VB': 2, 'NNS': 2, 'CC': 2, 'DT': 1, 'CD': 1, 'VBP': 1, 'EX': 1, 'VBZ': 1, 'JJS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 216:
# Counter({'PERSON': 1})
# --------------------------------------------------
# POS Tagging for Review 216:
# Counter({'NN': 15, 'JJ': 6, 'RB': 4, 'VB': 2, 'NNP': 2, 'CC': 2, 'PRP$': 1, 'VBN': 1, 'RBR': 1, 'DT': 1, 'IN': 1, 'PRP': 1, 'JJS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 217:
# Counter({'PERSON': 3})
# --------------------------------------------------
# POS Tagging for Review 217:
# Counter({'NN': 30, 'RB': 7, 'NNP': 6, 'VBD': 5, 'IN': 5, 'PRP': 4, 'VBP': 4, 'JJ': 3, 'VBZ': 1, 'CD': 1, 'JJS': 1, 'DT': 1, 'VBG': 1, 'VBN': 1, 'EX': 1, 'VB': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 218:
# Counter({'ORGANIZATION': 3, 'PERSON': 3})
# --------------------------------------------------
# POS Tagging for Review 218:
# Counter({'NN': 31, 'JJ': 16, 'RB': 10, 'NNP': 9, 'VBP': 8, 'PRP': 8, 'VBD': 7, 'NNS': 6, 'DT': 5, 'VBG': 5, 'IN': 4, 'VB': 3, 'VBZ': 2, 'CD': 1, 'JJS': 1, 'RBR': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 219:
# Counter()
# --------------------------------------------------
# POS Tagging for Review 219:
# Counter({'NN': 4, 'JJ': 2, 'RB': 1, 'VBP': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 220:
# Counter({'PERSON': 25, 'ORGANIZATION': 3})
# --------------------------------------------------
# POS Tagging for Review 220:
# Counter({'NN': 109, 'NNP': 50, 'JJ': 44, 'VBD': 27, 'VBG': 19, 'VB': 14, 'VBP': 14, 'RB': 14, 'VBN': 8, 'IN': 6, 'CD': 6, 'VBZ': 4, 'NNS': 4, 'DT': 3, 'PRP': 3, 'MD': 2, 'RBR': 2, 'JJS': 1, 'PRP$': 1, 'JJR': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 221:
# Counter()
# --------------------------------------------------
# POS Tagging for Review 221:
# Counter({'NN': 5, 'CD': 1, 'NNP': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 222:
# Counter({'PERSON': 12, 'ORGANIZATION': 2})
# --------------------------------------------------
# POS Tagging for Review 222:
# Counter({'NN': 95, 'JJ': 49, 'NNP': 32, 'RB': 27, 'VBP': 23, 'VBG': 20, 'PRP': 17, 'VB': 10, 'VBD': 10, 'CC': 8, 'DT': 7, 'NNS': 6, 'VBZ': 6, 'VBN': 5, 'IN': 5, 'MD': 1, 'CD': 1, 'JJS': 1, 'EX': 1, 'PRP$': 1, 'TO': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 223:
# Counter({'PERSON': 32, 'ORGANIZATION': 6, 'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 223:
# Counter({'NN': 146, 'NNP': 73, 'JJ': 44, 'PRP': 30, 'VBD': 27, 'VBP': 23, 'RB': 19, 'VBN': 16, 'VBG': 11, 'CD': 7, 'IN': 7, 'DT': 6, 'VBZ': 5, 'NNS': 4, 'VB': 3, 'MD': 2, 'WRB': 1, 'JJS': 1, 'CC': 1, 'JJR': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 224:
# Counter({'PERSON': 2})
# --------------------------------------------------
# POS Tagging for Review 224:
# Counter({'NN': 18, 'JJ': 12, 'NNP': 8, 'NNS': 4, 'RB': 4, 'VBP': 3, 'DT': 3, 'CD': 1, 'IN': 1, 'JJS': 1, 'VB': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 225:
# Counter()
# --------------------------------------------------
# POS Tagging for Review 225:
# Counter({'NN': 17, 'RB': 9, 'PRP': 7, 'JJ': 5, 'VBD': 4, 'NNP': 3, 'VBP': 3, 'CD': 2, 'CC': 2, 'VB': 2, 'JJS': 1, 'VBN': 1, 'VBG': 1, 'DT': 1, 'IN': 1, 'VBZ': 1, 'MD': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 226:
# Counter({'PERSON': 9, 'GPE': 1, 'ORGANIZATION': 1})
# --------------------------------------------------
# POS Tagging for Review 226:
# Counter({'NN': 83, 'JJ': 55, 'NNP': 22, 'RB': 14, 'NNS': 8, 'VBP': 8, 'VBG': 8, 'VBD': 7, 'VB': 7, 'VBN': 5, 'MD': 4, 'IN': 3, 'PRP': 2, 'RBR': 2, 'CD': 2, 'VBZ': 2, 'PRP$': 1, 'NNPS': 1, 'CC': 1, 'DT': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 227:
# Counter({'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 227:
# Counter({'NNP': 3, 'NN': 2, 'VBP': 1, 'CC': 1, 'JJ': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 228:
# Counter({'ORGANIZATION': 2, 'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 228:
# Counter({'NN': 24, 'VBD': 5, 'JJ': 5, 'RB': 3, 'VBP': 2, 'VBG': 2, 'NNS': 2, 'NNP': 1, 'VB': 1, 'IN': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 229:
# Counter({'PERSON': 2})
# --------------------------------------------------
# POS Tagging for Review 229:
# Counter({'NNP': 5})
# --------------------------------------------------
# Named Entity Recognition for Review 230:
# Counter()
# --------------------------------------------------
# POS Tagging for Review 230:
# Counter({'NN': 8, 'JJ': 3, 'RB': 3, 'VBG': 2, 'IN': 1, 'VBN': 1, 'NNP': 1, 'NNS': 1, 'VBP': 1, 'VBD': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 231:
# Counter({'PERSON': 1})
# --------------------------------------------------
# POS Tagging for Review 231:
# Counter({'NN': 17, 'RB': 13, 'JJ': 10, 'VBP': 5, 'VBG': 4, 'NNP': 4, 'PRP': 3, 'VB': 2, 'VBN': 2, 'VBD': 2, 'DT': 1, 'CD': 1, 'PRP$': 1, 'VBZ': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 232:
# Counter({'PERSON': 2, 'ORGANIZATION': 1})
# --------------------------------------------------
# POS Tagging for Review 232:
# Counter({'NN': 13, 'RB': 9, 'PRP': 8, 'VBD': 6, 'JJ': 5, 'VBP': 3, 'NNP': 3, 'VBN': 1, 'DT': 1, 'VBG': 1, 'NNS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 233:
# Counter({'PERSON': 20, 'ORGANIZATION': 16})
# --------------------------------------------------
# POS Tagging for Review 233:
# Counter({'NN': 116, 'NNP': 82, 'JJ': 59, 'RB': 16, 'VBD': 15, 'VBP': 15, 'DT': 14, 'VBZ': 9, 'PRP': 8, 'IN': 7, 'VB': 7, 'VBG': 6, 'VBN': 5, 'NNS': 4, 'JJR': 1, 'CC': 1, 'MD': 1, 'RBR': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 234:
# Counter({'PERSON': 13, 'ORGANIZATION': 7, 'GPE': 2})
# --------------------------------------------------
# POS Tagging for Review 234:
# Counter({'NN': 88, 'NNP': 41, 'JJ': 39, 'PRP': 28, 'VBP': 27, 'RB': 26, 'VBD': 18, 'VBN': 10, 'NNS': 8, 'VBG': 6, 'IN': 6, 'VB': 5, 'CD': 3, 'JJS': 3, 'CC': 3, 'DT': 2, 'WRB': 2, 'VBZ': 2, 'MD': 2, 'RBR': 1, 'WP': 1, 'TO': 1, 'JJR': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 235:
# Counter({'PERSON': 15, 'ORGANIZATION': 2, 'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 235:
# Counter({'NN': 102, 'JJ': 50, 'NNP': 33, 'RB': 23, 'VBP': 14, 'VBG': 12, 'PRP': 8, 'CD': 8, 'VBZ': 8, 'VBD': 7, 'IN': 7, 'NNS': 4, 'EX': 4, 'VBN': 4, 'VB': 4, 'DT': 4, 'WRB': 2, 'JJS': 1, 'NNPS': 1, 'WP': 1, 'JJR': 1, 'CC': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 236:
# Counter({'PERSON': 6, 'ORGANIZATION': 1})
# --------------------------------------------------
# POS Tagging for Review 236:
# Counter({'NN': 27, 'NNP': 20, 'JJ': 11, 'VBG': 7, 'DT': 7, 'RB': 5, 'JJS': 2, 'VB': 2, 'VBZ': 2, 'CD': 1, 'IN': 1, 'VBP': 1, 'VBD': 1, 'PRP': 1, 'MD': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 237:
# Counter({'PERSON': 6, 'ORGANIZATION': 1})
# --------------------------------------------------
# POS Tagging for Review 237:
# Counter({'NN': 34, 'NNP': 15, 'RB': 8, 'JJ': 6, 'VBD': 5, 'VBG': 5, 'VBN': 5, 'IN': 4, 'VBP': 4, 'VBZ': 3, 'PRP': 2, 'FW': 1, 'NNS': 1, 'CC': 1, 'WP': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 238:
# Counter({'PERSON': 5, 'ORGANIZATION': 1})
# --------------------------------------------------
# POS Tagging for Review 238:
# Counter({'NN': 53, 'JJ': 36, 'RB': 12, 'NNP': 11, 'VBP': 9, 'DT': 7, 'PRP': 6, 'VB': 6, 'VBN': 5, 'VBD': 5, 'IN': 5, 'VBG': 5, 'MD': 2, 'VBZ': 2, 'CD': 2, 'NNS': 2, 'JJS': 1, 'CC': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 239:
# Counter()
# --------------------------------------------------
# POS Tagging for Review 239:
# Counter({'NN': 27, 'JJ': 11, 'VBG': 8, 'CD': 3, 'RB': 2, 'VBD': 2, 'DT': 1, 'IN': 1, 'NNP': 1, 'VBN': 1, 'VB': 1, 'NNS': 1, 'VBP': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 240:
# Counter({'PERSON': 3})
# --------------------------------------------------
# POS Tagging for Review 240:
# Counter({'NN': 22, 'RB': 14, 'JJ': 12, 'NNP': 10, 'PRP': 10, 'VBP': 10, 'VBD': 4, 'IN': 4, 'VBN': 3, 'MD': 3, 'VB': 2, 'WRB': 1, 'CD': 1, 'RBS': 1, 'VBZ': 1, 'VBG': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 241:
# Counter({'ORGANIZATION': 4, 'PERSON': 4})
# --------------------------------------------------
# POS Tagging for Review 241:
# Counter({'NN': 25, 'NNP': 19, 'JJ': 8, 'VBP': 6, 'RB': 4, 'IN': 4, 'DT': 2, 'VBG': 2, 'CD': 2, 'VB': 1, 'VBD': 1, 'VBN': 1, 'NNS': 1, 'JJS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 242:
# Counter({'PERSON': 3})
# --------------------------------------------------
# POS Tagging for Review 242:
# Counter({'NN': 30, 'NNP': 10, 'PRP': 9, 'VBD': 9, 'VBP': 6, 'RB': 6, 'JJ': 5, 'VBG': 5, 'VB': 4, 'DT': 4, 'MD': 2, 'JJS': 1, 'NNS': 1, 'VBN': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 243:
# Counter({'PERSON': 2})
# --------------------------------------------------
# POS Tagging for Review 243:
# Counter({'NN': 20, 'RB': 6, 'NNP': 6, 'JJ': 6, 'VBG': 5, 'PRP': 4, 'VBD': 3, 'VBP': 2, 'DT': 2, 'IN': 1, 'VBZ': 1, 'MD': 1, 'VB': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 244:
# Counter({'PERSON': 2, 'ORGANIZATION': 2, 'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 244:
# Counter({'NN': 18, 'NNP': 7, 'JJ': 6, 'VBG': 6, 'VBZ': 2, 'RB': 2, 'PRP': 1, 'IN': 1, 'VBD': 1, 'VBN': 1, 'NNS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 245:
# Counter({'ORGANIZATION': 1})
# --------------------------------------------------
# POS Tagging for Review 245:
# Counter({'NN': 9, 'RB': 4, 'JJ': 3, 'VBG': 2, 'PRP': 1, 'VBD': 1, 'VBN': 1, 'VBP': 1, 'IN': 1, 'MD': 1, 'VB': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 246:
# Counter({'PERSON': 2})
# --------------------------------------------------
# POS Tagging for Review 246:
# Counter({'NN': 10, 'VBD': 5, 'NNP': 4, 'JJ': 4, 'VBG': 3, 'VBN': 3, 'IN': 3, 'RB': 3, 'PRP': 3, 'VBP': 2, 'POS': 1, 'NNS': 1, 'VB': 1, 'CD': 1, 'JJR': 1, 'MD': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 247:
# Counter({'ORGANIZATION': 1})
# --------------------------------------------------
# POS Tagging for Review 247:
# Counter({'NN': 26, 'JJ': 15, 'PRP': 8, 'VBD': 7, 'VBG': 6, 'VBN': 4, 'RB': 3, 'VBP': 3, 'VB': 2, 'IN': 2, 'NNS': 2, 'DT': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 248:
# Counter({'PERSON': 4, 'ORGANIZATION': 1})
# --------------------------------------------------
# POS Tagging for Review 248:
# Counter({'NNP': 8, 'NN': 5, 'JJ': 4, 'NNS': 2, 'VBD': 2, 'IN': 1, 'PRP': 1, 'VBP': 1, 'PRP$': 1, 'VBN': 1, 'CC': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 249:
# Counter({'PERSON': 1})
# --------------------------------------------------
# POS Tagging for Review 249:
# Counter({'NN': 25, 'JJ': 12, 'RB': 4, 'PRP': 3, 'VBN': 3, 'VBD': 3, 'VB': 2, 'NNP': 2, 'VBP': 2, 'DT': 2, 'TO': 1, 'JJS': 1, 'CC': 1, 'NNS': 1, 'IN': 1, 'VBG': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 250:
# Counter({'GPE': 3, 'PERSON': 3})
# --------------------------------------------------
# POS Tagging for Review 250:
# Counter({'NN': 48, 'JJ': 20, 'NNP': 11, 'RB': 7, 'VBG': 5, 'VBP': 4, 'CC': 4, 'VBD': 4, 'NNS': 3, 'DT': 2, 'VBN': 1, 'VBZ': 1, 'IN': 1, 'PRP': 1, 'WP': 1, 'VB': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 251:
# Counter({'ORGANIZATION': 2, 'PERSON': 1})
# --------------------------------------------------
# POS Tagging for Review 251:
# Counter({'NN': 19, 'NNP': 9, 'JJ': 7, 'RB': 5, 'VBG': 3, 'IN': 3, 'VBP': 2, 'VB': 2, 'NNS': 2, 'DT': 1, 'VBD': 1, 'PRP': 1, 'MD': 1, 'VBN': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 252:
# Counter({'PERSON': 10, 'ORGANIZATION': 2})
# --------------------------------------------------
# POS Tagging for Review 252:
# Counter({'NN': 121, 'JJ': 45, 'VBD': 24, 'RB': 19, 'VBG': 14, 'NNP': 14, 'PRP': 14, 'VBP': 11, 'VBN': 11, 'VBZ': 8, 'NNS': 6, 'DT': 6, 'IN': 6, 'VB': 5, 'CD': 3, 'TO': 1, 'JJS': 1, 'WP': 1, 'RBR': 1, 'CC': 1, 'JJR': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 253:
# Counter({'PERSON': 1})
# --------------------------------------------------
# POS Tagging for Review 253:
# Counter({'NN': 20, 'JJ': 8, 'NNP': 6, 'RB': 4, 'PRP': 4, 'VBP': 4, 'NNS': 2, 'DT': 2, 'VBD': 2, 'CD': 1, 'IN': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 254:
# Counter({'ORGANIZATION': 2})
# --------------------------------------------------
# POS Tagging for Review 254:
# Counter({'NN': 25, 'JJ': 14, 'RB': 6, 'VBG': 4, 'IN': 3, 'VBD': 3, 'VBN': 2, 'NNS': 2, 'VBP': 2, 'DT': 1, 'VBZ': 1, 'VB': 1, 'JJR': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 255:
# Counter({'PERSON': 8, 'ORGANIZATION': 3, 'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 255:
# Counter({'NN': 72, 'JJ': 37, 'NNP': 26, 'RB': 16, 'VBG': 13, 'VBD': 8, 'VBP': 7, 'VB': 6, 'IN': 5, 'PRP': 3, 'DT': 2, 'NNS': 2, 'VBZ': 2, 'VBN': 2, 'CD': 2, 'JJS': 1, 'RBR': 1, 'CC': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 256:
# Counter({'PERSON': 3})
# --------------------------------------------------
# POS Tagging for Review 256:
# Counter({'NN': 19, 'NNP': 11, 'PRP': 7, 'RB': 6, 'JJ': 6, 'VBP': 6, 'VBD': 5, 'VB': 3, 'MD': 2, 'PRP$': 1, 'IN': 1, 'CD': 1, 'JJS': 1, 'CC': 1, 'VBG': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 257:
# Counter({'PERSON': 5, 'ORGANIZATION': 2})
# --------------------------------------------------
# POS Tagging for Review 257:
# Counter({'NN': 32, 'NNP': 27, 'JJ': 16, 'RB': 5, 'VBP': 4, 'IN': 4, 'VBN': 4, 'DT': 3, 'VBD': 3, 'VBG': 3, 'VB': 3, 'PRP': 2, 'MD': 2, 'CD': 1, 'JJS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 258:
# Counter({'ORGANIZATION': 5, 'PERSON': 1})
# --------------------------------------------------
# POS Tagging for Review 258:
# Counter({'NN': 102, 'JJ': 43, 'RB': 21, 'VBP': 15, 'VBD': 10, 'VBN': 7, 'VB': 4, 'IN': 4, 'VBG': 4, 'VBZ': 4, 'NNS': 4, 'NNP': 4, 'DT': 3, 'MD': 3, 'JJR': 2, 'CD': 2, 'CC': 2, 'JJS': 1, 'UH': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 259:
# Counter({'PERSON': 6, 'ORGANIZATION': 4})
# --------------------------------------------------
# POS Tagging for Review 259:
# Counter({'NN': 58, 'NNP': 31, 'JJ': 21, 'RB': 9, 'VBG': 8, 'VBD': 5, 'VB': 5, 'PRP': 4, 'DT': 4, 'VBZ': 3, 'VBP': 3, 'VBN': 2, 'MD': 2, 'IN': 2, 'CD': 1, 'NNS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 260:
# Counter({'PERSON': 2})
# --------------------------------------------------
# POS Tagging for Review 260:
# Counter({'NN': 34, 'JJ': 16, 'RB': 7, 'VBG': 6, 'MD': 6, 'NNP': 6, 'VB': 5, 'VBP': 5, 'IN': 4, 'DT': 3, 'NNS': 2, 'VBD': 1, 'PRP': 1, 'RBS': 1, 'WP': 1, 'JJR': 1, 'EX': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 261:
# Counter({'PERSON': 3, 'ORGANIZATION': 3, 'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 261:
# Counter({'NN': 23, 'JJ': 21, 'NNP': 13, 'VBP': 13, 'RB': 5, 'IN': 4, 'PRP': 4, 'VBN': 3, 'VBG': 2, 'NNS': 2, 'CD': 2, 'VBZ': 1, 'DT': 1, 'RBR': 1, 'VBD': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 262:
# Counter({'PERSON': 1})
# --------------------------------------------------
# POS Tagging for Review 262:
# Counter({'NN': 2, 'NNP': 2, 'JJ': 1, 'RB': 1, 'VBZ': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 263:
# Counter({'PERSON': 11, 'ORGANIZATION': 2, 'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 263:
# Counter({'NN': 53, 'NNP': 29, 'JJ': 21, 'RB': 12, 'VBP': 7, 'VBG': 7, 'VBD': 4, 'DT': 4, 'VB': 4, 'PRP': 3, 'VBN': 3, 'IN': 3, 'NNS': 2, 'CD': 1, 'CC': 1, 'WP': 1, 'VBZ': 1, 'RP': 1, 'MD': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 264:
# Counter({'PERSON': 4, 'ORGANIZATION': 1})
# --------------------------------------------------
# POS Tagging for Review 264:
# Counter({'NN': 46, 'JJ': 12, 'VB': 10, 'NNP': 10, 'VBG': 7, 'DT': 7, 'PRP': 6, 'RB': 6, 'VBP': 4, 'VBD': 4, 'MD': 4, 'IN': 4, 'VBN': 3, 'NNS': 2, 'VBZ': 2, 'TO': 1, 'CD': 1, 'RP': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 265:
# Counter({'PERSON': 11, 'ORGANIZATION': 4, 'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 265:
# Counter({'NN': 143, 'JJ': 69, 'NNP': 22, 'RB': 17, 'VBD': 17, 'VBG': 16, 'VBP': 14, 'DT': 9, 'NNS': 9, 'VBZ': 9, 'IN': 8, 'VBN': 8, 'VB': 7, 'PRP': 5, 'JJR': 2, 'CD': 1, 'WP': 1, 'JJS': 1, 'WRB': 1, 'RP': 1, 'CC': 1, 'RBR': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 266:
# Counter({'PERSON': 20, 'ORGANIZATION': 6})
# --------------------------------------------------
# POS Tagging for Review 266:
# Counter({'NN': 159, 'JJ': 73, 'NNP': 61, 'RB': 39, 'VBP': 37, 'PRP': 34, 'VBD': 24, 'VBG': 22, 'IN': 15, 'VB': 14, 'NNS': 12, 'VBZ': 12, 'VBN': 11, 'CD': 7, 'WRB': 4, 'DT': 4, 'MD': 3, 'JJR': 2, 'JJS': 1, 'TO': 1, 'EX': 1, 'RBR': 1, 'CC': 1, 'PRP$': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 267:
# Counter({'PERSON': 3, 'GPE': 2})
# --------------------------------------------------
# POS Tagging for Review 267:
# Counter({'JJ': 12, 'NN': 11, 'VBD': 6, 'NNP': 6, 'PRP': 4, 'RB': 3, 'VBP': 3, 'DT': 1, 'PRP$': 1, 'JJS': 1, 'VBN': 1, 'IN': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 268:
# Counter({'PERSON': 8, 'ORGANIZATION': 6, 'GSP': 1, 'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 268:
# Counter({'NN': 84, 'JJ': 45, 'NNP': 37, 'RB': 33, 'VBG': 16, 'VBP': 14, 'PRP': 13, 'VB': 13, 'VBD': 8, 'IN': 6, 'NNS': 6, 'CC': 6, 'VBN': 5, 'MD': 5, 'CD': 4, 'VBZ': 3, 'JJR': 2, 'UH': 1, 'WP': 1, 'TO': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 269:
# Counter({'PERSON': 5, 'ORGANIZATION': 4})
# --------------------------------------------------
# POS Tagging for Review 269:
# Counter({'NN': 25, 'NNP': 20, 'JJ': 19, 'RB': 4, 'IN': 3, 'PRP': 3, 'VBD': 3, 'VBP': 2, 'DT': 2, 'TO': 2, 'VBZ': 1, 'NNS': 1, 'MD': 1, 'VB': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 270:
# Counter({'PERSON': 6, 'ORGANIZATION': 3})
# --------------------------------------------------
# POS Tagging for Review 270:
# Counter({'NN': 49, 'JJ': 20, 'NNP': 17, 'PRP': 7, 'VBG': 7, 'RB': 6, 'IN': 6, 'VBD': 3, 'VBN': 3, 'NNS': 3, 'VBP': 3, 'VB': 2, 'WP': 2, 'VBZ': 2, 'CD': 1, 'JJS': 1, 'PRP$': 1, 'FW': 1, 'MD': 1, 'DT': 1, 'CC': 1, 'JJR': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 271:
# Counter({'PERSON': 13, 'GPE': 6, 'ORGANIZATION': 5})
# --------------------------------------------------
# POS Tagging for Review 271:
# Counter({'NN': 100, 'JJ': 54, 'NNP': 44, 'RB': 23, 'VBD': 22, 'VBP': 19, 'PRP': 19, 'VBG': 10, 'VB': 10, 'MD': 6, 'VBN': 4, 'NNS': 4, 'DT': 4, 'IN': 4, 'VBZ': 4, 'JJR': 3, 'CD': 2, 'WP': 1, 'JJS': 1, 'NNPS': 1, 'CC': 1, 'POS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 272:
# Counter({'PERSON': 22, 'ORGANIZATION': 7, 'GPE': 3})
# --------------------------------------------------
# POS Tagging for Review 272:
# Counter({'NN': 158, 'JJ': 97, 'NNP': 62, 'RB': 42, 'VBP': 22, 'PRP': 19, 'VBG': 19, 'VBD': 15, 'VBZ': 13, 'IN': 12, 'DT': 11, 'VB': 11, 'CD': 9, 'VBN': 8, 'NNS': 8, 'MD': 5, 'JJS': 4, 'JJR': 3, 'CC': 2, 'TO': 2, 'WP$': 1, 'EX': 1, 'WRB': 1, 'WDT': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 273:
# Counter({'PERSON': 3})
# --------------------------------------------------
# POS Tagging for Review 273:
# Counter({'NN': 10, 'JJ': 10, 'NNP': 6, 'CD': 5, 'IN': 2, 'VBG': 2, 'VBN': 2, 'PRP': 2, 'VBZ': 1, 'RB': 1, 'NNS': 1, 'VBP': 1, 'MD': 1, 'VB': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 274:
# Counter({'ORGANIZATION': 5})
# --------------------------------------------------
# POS Tagging for Review 274:
# Counter({'NN': 22, 'NNP': 15, 'JJ': 14, 'RB': 8, 'IN': 3, 'VBG': 3, 'VB': 3, 'VBP': 3, 'VBD': 2, 'PRP': 2, 'DT': 1, 'VBN': 1, 'MD': 1, 'NNS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 275:
# Counter({'PERSON': 18, 'ORGANIZATION': 2, 'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 275:
# Counter({'NN': 118, 'JJ': 67, 'NNP': 44, 'RB': 38, 'VBG': 18, 'VBD': 11, 'VBP': 10, 'IN': 8, 'NNS': 8, 'VBN': 6, 'VB': 5, 'VBZ': 4, 'CD': 4, 'JJS': 4, 'DT': 3, 'EX': 1, 'MD': 1, 'PRP$': 1, 'UH': 1, 'WP': 1, 'PRP': 1, 'CC': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 276:
# Counter({'ORGANIZATION': 2, 'PERSON': 2})
# --------------------------------------------------
# POS Tagging for Review 276:
# Counter({'NN': 10, 'JJ': 6, 'NNP': 6, 'VBG': 2, 'WP': 1, 'PRP': 1, 'VBP': 1, 'RB': 1, 'VB': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 277:
# Counter({'ORGANIZATION': 1, 'PERSON': 1})
# --------------------------------------------------
# POS Tagging for Review 277:
# Counter({'NN': 16, 'JJ': 9, 'RB': 4, 'VBG': 3, 'VB': 3, 'NNP': 3, 'PRP': 2, 'VBP': 2, 'MD': 2, 'VBD': 2, 'JJR': 1, 'JJS': 1, 'NNS': 1, 'VBN': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 278:
# Counter({'PERSON': 4, 'ORGANIZATION': 1})
# --------------------------------------------------
# POS Tagging for Review 278:
# Counter({'NN': 41, 'JJ': 17, 'NNP': 13, 'RB': 11, 'VBD': 10, 'PRP': 8, 'VBG': 5, 'IN': 4, 'VBP': 4, 'VB': 4, 'VBN': 3, 'WRB': 2, 'CD': 2, 'RP': 1, 'DT': 1, 'VBZ': 1, 'NNS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 279:
# Counter({'ORGANIZATION': 3, 'PERSON': 1})
# --------------------------------------------------
# POS Tagging for Review 279:
# Counter({'NN': 18, 'NNP': 10, 'RB': 6, 'JJ': 6, 'VB': 5, 'PRP': 4, 'DT': 3, 'VBG': 3, 'MD': 2, 'PRP$': 2, 'VBP': 2, 'IN': 2, 'CD': 1, 'JJS': 1, 'WRB': 1, 'CC': 1, 'NNS': 1, 'VBD': 1, 'VBZ': 1, 'RP': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 280:
# Counter()
# --------------------------------------------------
# POS Tagging for Review 280:
# Counter({'NN': 23, 'JJ': 12, 'RB': 4, 'VBG': 4, 'NNS': 2, 'VBP': 2, 'IN': 2, 'VB': 2, 'DT': 1, 'VBD': 1, 'VBZ': 1, 'MD': 1, 'VBN': 1, 'JJS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 281:
# Counter({'GPE': 1, 'ORGANIZATION': 1})
# --------------------------------------------------
# POS Tagging for Review 281:
# Counter({'NN': 35, 'JJ': 11, 'VBD': 7, 'NNP': 5, 'VBP': 5, 'PRP': 3, 'VBZ': 3, 'DT': 2, 'RB': 2, 'NNS': 2, 'IN': 2, 'WRB': 1, 'CD': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 282:
# Counter({'PERSON': 12, 'ORGANIZATION': 3})
# --------------------------------------------------
# POS Tagging for Review 282:
# Counter({'NN': 72, 'NNP': 24, 'JJ': 21, 'PRP': 18, 'VBP': 16, 'RB': 11, 'VBD': 11, 'IN': 9, 'VBG': 9, 'VBN': 5, 'VBZ': 3, 'VB': 3, 'CD': 2, 'JJR': 2, 'DT': 2, 'RBR': 1, 'JJS': 1, 'PRP$': 1, 'MD': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 283:
# Counter({'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 283:
# Counter({'NN': 9, 'JJ': 6, 'VBP': 3, 'NNS': 2, 'VBD': 2, 'VBN': 1, 'VB': 1, 'VBG': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 284:
# Counter({'PERSON': 1})
# --------------------------------------------------
# POS Tagging for Review 284:
# Counter({'NN': 6, 'VBD': 3, 'PRP': 2, 'JJ': 2, 'CC': 1, 'VBP': 1, 'VB': 1, 'DT': 1, 'RB': 1, 'NNP': 1, 'VBG': 1, 'IN': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 285:
# Counter({'PERSON': 1})
# --------------------------------------------------
# POS Tagging for Review 285:
# Counter({'NN': 7, 'JJ': 4, 'DT': 1, 'NNP': 1, 'RB': 1, 'VBP': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 286:
# Counter({'ORGANIZATION': 4})
# --------------------------------------------------
# POS Tagging for Review 286:
# Counter({'NN': 37, 'JJ': 21, 'RB': 12, 'VBD': 9, 'IN': 9, 'VBP': 7, 'CD': 4, 'VBG': 3, 'NNP': 2, 'PRP': 2, 'PRP$': 2, 'CC': 1, 'VBN': 1, 'VBZ': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 287:
# Counter({'ORGANIZATION': 3, 'PERSON': 1})
# --------------------------------------------------
# POS Tagging for Review 287:
# Counter({'NN': 12, 'NNP': 4, 'VB': 3, 'RB': 3, 'JJ': 2, 'VBD': 1, 'DT': 1, 'MD': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 288:
# Counter({'ORGANIZATION': 2})
# --------------------------------------------------
# POS Tagging for Review 288:
# Counter({'NN': 13, 'JJ': 10, 'NNP': 8, 'VBD': 2, 'DT': 1, 'VBN': 1, 'NNS': 1, 'RB': 1, 'VBG': 1, 'VBP': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 289:
# Counter()
# --------------------------------------------------
# POS Tagging for Review 289:
# Counter({'JJ': 2, 'IN': 1, 'NN': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 290:
# Counter({'ORGANIZATION': 10, 'PERSON': 1})
# --------------------------------------------------
# POS Tagging for Review 290:
# Counter({'NNP': 33, 'NN': 14, 'JJ': 8, 'RB': 4, 'PRP': 3, 'VBG': 2, 'IN': 2, 'VBD': 1, 'VBP': 1, 'PRP$': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 291:
# Counter()
# --------------------------------------------------
# POS Tagging for Review 291:
# Counter({'NN': 2, 'PRP': 1, 'VBP': 1, 'JJ': 1, 'NNP': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 292:
# Counter({'PERSON': 14, 'ORGANIZATION': 7, 'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 292:
# Counter({'NN': 159, 'JJ': 65, 'NNP': 35, 'RB': 29, 'VBD': 21, 'VBG': 15, 'VBP': 13, 'VBZ': 12, 'VBN': 12, 'DT': 9, 'PRP': 7, 'NNS': 6, 'VB': 5, 'CD': 3, 'IN': 2, 'EX': 2, 'PRP$': 2, 'MD': 2, 'PDT': 1, 'NNPS': 1, 'JJS': 1, 'RP': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 293:
# Counter({'ORGANIZATION': 3})
# --------------------------------------------------
# POS Tagging for Review 293:
# Counter({'NN': 15, 'JJ': 7, 'VBG': 4, 'VBD': 3, 'PRP': 2, 'VBP': 2, 'RB': 2, 'IN': 1, 'PDT': 1, 'DT': 1, 'VBN': 1, 'NNS': 1, 'VB': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 294:
# Counter({'PERSON': 13, 'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 294:
# Counter({'NN': 47, 'NNP': 31, 'JJ': 15, 'VBD': 8, 'VBP': 7, 'PRP': 6, 'RB': 6, 'VB': 4, 'VBG': 4, 'VBN': 3, 'NNS': 3, 'IN': 3, 'DT': 1, 'VBZ': 1, 'CD': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 295:
# Counter({'PERSON': 14, 'ORGANIZATION': 2, 'GPE': 2})
# --------------------------------------------------
# POS Tagging for Review 295:
# Counter({'NN': 107, 'JJ': 46, 'RB': 30, 'NNP': 30, 'VBP': 20, 'VBG': 16, 'IN': 12, 'VB': 11, 'VBN': 10, 'NNS': 10, 'PRP': 10, 'DT': 9, 'CD': 5, 'MD': 5, 'VBD': 5, 'VBZ': 4, 'JJS': 1, 'UH': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 296:
# Counter({'PERSON': 7})
# --------------------------------------------------
# POS Tagging for Review 296:
# Counter({'NN': 33, 'NNP': 19, 'JJ': 7, 'RB': 7, 'PRP': 5, 'VBG': 5, 'VBP': 5, 'VBZ': 3, 'VB': 3, 'IN': 2, 'PRP$': 2, 'DT': 2, 'JJS': 1, 'CD': 1, 'RBR': 1, 'VBN': 1, 'VBD': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 297:
# Counter({'PERSON': 1})
# --------------------------------------------------
# POS Tagging for Review 297:
# Counter({'NN': 22, 'JJ': 8, 'NNP': 5, 'VB': 4, 'CD': 4, 'RB': 4, 'VBG': 3, 'VBZ': 3, 'IN': 2, 'DT': 2, 'VBP': 2, 'VBN': 1, 'RBR': 1, 'VBD': 1, 'JJS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 298:
# Counter({'ORGANIZATION': 4})
# --------------------------------------------------
# POS Tagging for Review 298:
# Counter({'NNP': 14, 'NN': 6, 'VBP': 4, 'IN': 2, 'DT': 1, 'JJ': 1, 'VBG': 1, 'VBZ': 1, 'RB': 1, 'PRP': 1, 'VBD': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 299:
# Counter({'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 299:
# Counter({'NN': 13, 'JJ': 5, 'VBP': 3, 'VBD': 2, 'IN': 2, 'RB': 2, 'CD': 2, 'NNS': 1, 'PRP': 1, 'DT': 1, 'VBG': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 300:
# Counter({'ORGANIZATION': 5, 'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 300:
# Counter({'NN': 29, 'JJ': 17, 'RB': 10, 'NNP': 9, 'VBD': 7, 'VBP': 4, 'VBG': 4, 'PRP': 3, 'VB': 3, 'IN': 3, 'NNS': 2, 'MD': 2, 'RP': 1, 'VBN': 1, 'NNPS': 1, 'VBZ': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 301:
# Counter({'PERSON': 9, 'ORGANIZATION': 3, 'GPE': 2})
# --------------------------------------------------
# POS Tagging for Review 301:
# Counter({'NN': 60, 'NNP': 35, 'JJ': 34, 'PRP': 19, 'VBD': 18, 'VBP': 13, 'RB': 13, 'IN': 7, 'VBG': 7, 'DT': 5, 'VB': 5, 'VBN': 4, 'CD': 3, 'NNS': 2, 'JJS': 2, 'RBR': 1, 'VBZ': 1, 'CC': 1, 'MD': 1, 'JJR': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 302:
# Counter({'PERSON': 1, 'ORGANIZATION': 1, 'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 302:
# Counter({'NN': 17, 'JJ': 10, 'NNP': 9, 'RB': 4, 'VBN': 2, 'VBD': 2, 'VBG': 2, 'IN': 2, 'PRP': 2, 'VB': 2, 'CD': 1, 'JJS': 1, 'NNS': 1, 'VBP': 1, 'DT': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 303:
# Counter({'PERSON': 2})
# --------------------------------------------------
# POS Tagging for Review 303:
# Counter({'NN': 38, 'JJ': 14, 'RB': 8, 'VBD': 6, 'VBP': 4, 'VBG': 4, 'VB': 4, 'NNP': 4, 'PRP': 3, 'VBN': 3, 'RBR': 2, 'IN': 2, 'NNS': 1, 'DT': 1, 'VBZ': 1, 'JJR': 1, 'MD': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 304:
# Counter({'PERSON': 4, 'ORGANIZATION': 2})
# --------------------------------------------------
# POS Tagging for Review 304:
# Counter({'NN': 42, 'JJ': 16, 'NNP': 12, 'RB': 9, 'VBD': 6, 'VBP': 5, 'VB': 4, 'VBZ': 3, 'NNS': 3, 'VBG': 3, 'PRP': 3, 'IN': 2, 'MD': 2, 'WRB': 1, 'DT': 1, 'PRP$': 1, 'VBN': 1, 'CD': 1, 'JJS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 305:
# Counter({'PERSON': 8, 'ORGANIZATION': 3})
# --------------------------------------------------
# POS Tagging for Review 305:
# Counter({'NN': 29, 'NNP': 25, 'JJ': 16, 'RB': 12, 'VBD': 8, 'VBP': 8, 'VBG': 4, 'VB': 4, 'PRP': 3, 'IN': 2, 'MD': 2, 'VBZ': 2, 'UH': 1, 'CD': 1, 'NNS': 1, 'CC': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 306:
# Counter({'PERSON': 5})
# --------------------------------------------------
# POS Tagging for Review 306:
# Counter({'NN': 29, 'NNP': 15, 'JJ': 14, 'VBP': 9, 'PRP': 4, 'IN': 3, 'VB': 3, 'VBG': 3, 'VBN': 3, 'RB': 2, 'DT': 2, 'VBD': 2, 'NNS': 1, 'CD': 1, 'VBZ': 1, 'JJR': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 307:
# Counter()
# --------------------------------------------------
# POS Tagging for Review 307:
# Counter({'NN': 8, 'RB': 2, 'JJ': 2, 'PRP$': 1, 'JJS': 1, 'MD': 1, 'VB': 1, 'VBP': 1, 'JJR': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 308:
# Counter({'PERSON': 32, 'ORGANIZATION': 11})
# --------------------------------------------------
# POS Tagging for Review 308:
# Counter({'NN': 163, 'NNP': 75, 'JJ': 74, 'RB': 35, 'VBD': 20, 'VBG': 19, 'VB': 14, 'IN': 11, 'VBZ': 10, 'VBP': 9, 'VBN': 8, 'PRP': 8, 'CD': 8, 'DT': 8, 'MD': 4, 'NNS': 2, 'EX': 2, 'JJS': 2, 'TO': 1, 'JJR': 1, 'PRP$': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 309:
# Counter({'ORGANIZATION': 6})
# --------------------------------------------------
# POS Tagging for Review 309:
# Counter({'NNP': 34, 'NN': 4, 'DT': 2, 'RB': 2, 'JJS': 1, 'VBD': 1, 'VB': 1, 'PRP$': 1, 'CC': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 310:
# Counter({'PERSON': 21, 'ORGANIZATION': 4})
# --------------------------------------------------
# POS Tagging for Review 310:
# Counter({'NN': 212, 'JJ': 90, 'NNP': 45, 'RB': 33, 'VBP': 30, 'VBD': 26, 'VBG': 26, 'VB': 19, 'IN': 14, 'DT': 14, 'PRP': 13, 'VBZ': 10, 'NNS': 9, 'VBN': 8, 'CD': 4, 'MD': 3, 'CC': 3, 'WP': 2, 'PRP$': 2, 'JJR': 2, 'TO': 1, 'WRB': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 311:
# Counter({'PERSON': 8, 'ORGANIZATION': 4})
# --------------------------------------------------
# POS Tagging for Review 311:
# Counter({'NN': 62, 'JJ': 40, 'RB': 27, 'NNP': 19, 'VBG': 18, 'VB': 8, 'NNS': 8, 'VBP': 7, 'VBN': 6, 'IN': 6, 'VBD': 6, 'CD': 5, 'DT': 5, 'MD': 3, 'JJS': 1, 'VBZ': 1, 'CC': 1, 'PRP': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 312:
# Counter({'PERSON': 17, 'ORGANIZATION': 3})
# --------------------------------------------------
# POS Tagging for Review 312:
# Counter({'NN': 118, 'JJ': 59, 'NNP': 46, 'RB': 29, 'VBG': 19, 'VBD': 13, 'IN': 8, 'VBP': 8, 'VBN': 6, 'VB': 5, 'NNS': 5, 'DT': 5, 'VBZ': 4, 'PRP$': 3, 'MD': 2, 'RBR': 1, 'CD': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 313:
# Counter({'PERSON': 3, 'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 313:
# Counter({'NN': 38, 'JJ': 14, 'PRP': 11, 'VBG': 9, 'RB': 8, 'NNP': 7, 'VBP': 7, 'VBD': 6, 'IN': 4, 'VBN': 2, 'NNS': 2, 'DT': 1, 'JJR': 1, 'CC': 1, 'JJS': 1, 'EX': 1, 'VBZ': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 314:
# Counter({'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 314:
# Counter({'NN': 8, 'JJ': 8, 'NNP': 1, 'RB': 1, 'IN': 1, 'VBP': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 315:
# Counter({'PERSON': 3, 'GPE': 2, 'ORGANIZATION': 2})
# ...
# Counter({'PERSON': 1, 'ORGANIZATION': 1})
# --------------------------------------------------
# POS Tagging for Review 972:
# Counter({'NN': 28, 'RB': 14, 'JJ': 13, 'PRP': 7, 'VBD': 7, 'NNP': 7, 'VBG': 6, 'VBN': 4, 'VBP': 3, 'IN': 3, 'DT': 2, 'MD': 2, 'VB': 2, 'CD': 2, 'JJS': 1, 'JJR': 1, 'CC': 1, 'PRP$': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 973:
# Counter({'PERSON': 2})
# --------------------------------------------------
# POS Tagging for Review 973:
# Counter({'NN': 19, 'JJ': 14, 'VBG': 5, 'NNP': 4, 'DT': 3, 'PRP': 3, 'CD': 2, 'VB': 2, 'RB': 1, 'VBN': 1, 'VBD': 1, 'IN': 1, 'VBP': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 974:
# Counter({'GPE': 1, 'PERSON': 1})
# --------------------------------------------------
# POS Tagging for Review 974:
# Counter({'NN': 31, 'JJ': 16, 'RB': 6, 'VBD': 4, 'VBP': 4, 'VBG': 3, 'NNP': 2, 'NNS': 2, 'JJS': 2, 'VBN': 1, 'VB': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 975:
# Counter({'PERSON': 5, 'ORGANIZATION': 1})
# --------------------------------------------------
# POS Tagging for Review 975:
# Counter({'JJ': 15, 'NN': 15, 'NNP': 14, 'RB': 6, 'IN': 4, 'VBP': 4, 'NNS': 3, 'DT': 2, 'VBD': 2, 'VBG': 2, 'WRB': 1, 'VBN': 1, 'VBZ': 1, 'NNPS': 1, 'CC': 1, 'CD': 1, 'JJS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 976:
# Counter({'PERSON': 2, 'ORGANIZATION': 2})
# --------------------------------------------------
# POS Tagging for Review 976:
# Counter({'NN': 18, 'JJ': 15, 'NNP': 6, 'VBD': 5, 'PRP': 5, 'RB': 4, 'VBG': 3, 'VBP': 3, 'DT': 2, 'MD': 2, 'VB': 2, 'IN': 1, 'JJR': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 977:
# Counter({'PERSON': 2, 'GPE': 1, 'ORGANIZATION': 1})
# --------------------------------------------------
# POS Tagging for Review 977:
# Counter({'NN': 16, 'NNP': 10, 'JJ': 9, 'RB': 6, 'IN': 3, 'VBZ': 3, 'PRP': 2, 'VBP': 2, 'NNS': 2, 'VB': 2, 'VBN': 2, 'VBD': 2, 'TO': 1, 'JJS': 1, 'VBG': 1, 'CD': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 978:
# Counter({'PERSON': 2, 'ORGANIZATION': 1})
# --------------------------------------------------
# POS Tagging for Review 978:
# Counter({'NN': 19, 'JJ': 10, 'VBG': 7, 'NNP': 7, 'CD': 6, 'PRP': 5, 'RB': 5, 'VBD': 4, 'VBN': 4, 'VB': 3, 'MD': 2, 'VBP': 2, 'IN': 1, 'RP': 1, 'JJR': 1, 'RBR': 1, 'DT': 1, 'NNS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 979:
# Counter({'PERSON': 6, 'ORGANIZATION': 2})
# --------------------------------------------------
# POS Tagging for Review 979:
# Counter({'NN': 27, 'JJ': 13, 'NNP': 13, 'RB': 11, 'VBD': 8, 'IN': 6, 'VBG': 3, 'VBN': 3, 'PRP': 2, 'VBP': 1, 'PRP$': 1, 'DT': 1, 'WP': 1, 'EX': 1, 'NNPS': 1, 'JJS': 1, 'JJR': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 980:
# Counter({'PERSON': 13, 'ORGANIZATION': 5})
# --------------------------------------------------
# POS Tagging for Review 980:
# Counter({'NN': 91, 'JJ': 32, 'NNP': 30, 'VBG': 12, 'VBP': 10, 'RB': 9, 'VBZ': 8, 'VBD': 6, 'VB': 6, 'DT': 4, 'NNS': 4, 'IN': 3, 'JJR': 3, 'PRP': 2, 'CD': 2, 'CC': 2, 'UH': 1, 'FW': 1, 'VBN': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 981:
# Counter({'PERSON': 6, 'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 981:
# Counter({'NN': 15, 'NNP': 12, 'JJ': 6, 'VBP': 4, 'VBZ': 3, 'RB': 3, 'VBG': 3, 'DT': 2, 'MD': 2, 'VB': 2, 'VBD': 2, 'PRP': 2, 'RBR': 1, 'IN': 1, 'VBN': 1, 'NNS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 982:
# Counter({'PERSON': 2, 'ORGANIZATION': 1})
# --------------------------------------------------
# POS Tagging for Review 982:
# Counter({'NN': 10, 'NNP': 6, 'VB': 5, 'JJ': 4, 'DT': 3, 'RB': 3, 'VBG': 3, 'PRP': 2, 'VBD': 2, 'IN': 2, 'NNS': 1, 'MD': 1, 'VBP': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 983:
# Counter({'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 983:
# Counter({'NN': 101, 'JJ': 44, 'RB': 14, 'VBG': 11, 'VBP': 8, 'IN': 8, 'VB': 7, 'VBD': 7, 'CD': 5, 'VBN': 5, 'NNS': 5, 'JJS': 3, 'MD': 1, 'FW': 1, 'JJR': 1, 'RBR': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 984:
# Counter({'PERSON': 4, 'ORGANIZATION': 3})
# --------------------------------------------------
# POS Tagging for Review 984:
# Counter({'NN': 28, 'NNP': 14, 'JJ': 11, 'PRP': 5, 'VBD': 4, 'VBP': 4, 'VB': 3, 'VBG': 3, 'JJS': 3, 'RB': 2, 'VBZ': 1, 'CD': 1, 'NNS': 1, 'MD': 1, 'DT': 1, 'FW': 1, 'IN': 1, 'VBN': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 985:
# Counter({'GPE': 1, 'ORGANIZATION': 1})
# --------------------------------------------------
# POS Tagging for Review 985:
# Counter({'NN': 7, 'NNP': 6, 'JJ': 5, 'VBP': 3, 'VBN': 3, 'RB': 2, 'DT': 2, 'VBZ': 1, 'VB': 1, 'JJS': 1, 'NNS': 1, 'VBG': 1, 'CC': 1, 'IN': 1, 'PRP': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 986:
# Counter({'PERSON': 7, 'ORGANIZATION': 5})
# --------------------------------------------------
# POS Tagging for Review 986:
# Counter({'NN': 62, 'JJ': 27, 'NNP': 24, 'RB': 11, 'VBD': 8, 'DT': 6, 'VBN': 5, 'VBG': 5, 'VBP': 5, 'PRP': 5, 'PRP$': 3, 'IN': 3, 'NNS': 2, 'CD': 2, 'VBZ': 1, 'EX': 1, 'WP': 1, 'MD': 1, 'VB': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 987:
# Counter({'GPE': 2, 'ORGANIZATION': 2, 'PERSON': 1})
# --------------------------------------------------
# POS Tagging for Review 987:
# Counter({'NN': 39, 'JJ': 18, 'VBG': 7, 'PRP': 6, 'VBP': 6, 'RB': 5, 'NNP': 5, 'IN': 3, 'VBN': 3, 'VBD': 2, 'VB': 2, 'VBZ': 2, 'CD': 1, 'MD': 1, 'NNS': 1, 'DT': 1, 'JJR': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 988:
# Counter({'PERSON': 37, 'ORGANIZATION': 7, 'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 988:
# Counter({'NN': 114, 'NNP': 108, 'JJ': 43, 'RB': 23, 'VBD': 20, 'DT': 18, 'CD': 14, 'PRP': 11, 'VBN': 11, 'VBG': 10, 'VBP': 9, 'IN': 8, 'VB': 8, 'NNS': 7, 'VBZ': 5, 'CC': 2, 'MD': 2, 'JJS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 989:
# Counter()
# --------------------------------------------------
# POS Tagging for Review 989:
# Counter({'NN': 4, 'JJ': 4, 'DT': 1, 'VBN': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 990:
# Counter({'PERSON': 2, 'ORGANIZATION': 2})
# --------------------------------------------------
# POS Tagging for Review 990:
# Counter({'NNP': 10, 'JJ': 7, 'NN': 6, 'PRP': 2, 'VBP': 2, 'RB': 2, 'RBS': 1, 'IN': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 991:
# Counter({'ORGANIZATION': 1})
# --------------------------------------------------
# POS Tagging for Review 991:
# Counter({'NN': 16, 'JJ': 5, 'DT': 2, 'CD': 2, 'JJS': 2, 'IN': 1, 'PRP': 1, 'RB': 1, 'VBZ': 1, 'VBP': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 992:
# Counter({'ORGANIZATION': 5, 'PERSON': 1})
# --------------------------------------------------
# POS Tagging for Review 992:
# Counter({'NNP': 16, 'NN': 14, 'JJ': 7, 'VB': 2, 'VBG': 2, 'DT': 1, 'RB': 1, 'PRP': 1, 'CD': 1, 'JJS': 1, 'MD': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 993:
# Counter()
# --------------------------------------------------
# POS Tagging for Review 993:
# Counter({'NN': 7, 'JJ': 4, 'NNS': 2, 'RB': 2, 'VBZ': 1, 'VBG': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 994:
# Counter({'PERSON': 6, 'ORGANIZATION': 3})
# --------------------------------------------------
# POS Tagging for Review 994:
# Counter({'NN': 34, 'NNP': 19, 'JJ': 15, 'RB': 4, 'VB': 4, 'IN': 4, 'MD': 2, 'VBG': 2, 'VBP': 2, 'PRP': 2, 'VBZ': 1, 'CD': 1, 'VBN': 1, 'VBD': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 995:
# Counter({'PERSON': 3, 'ORGANIZATION': 1})
# --------------------------------------------------
# POS Tagging for Review 995:
# Counter({'NN': 30, 'JJ': 17, 'NNP': 8, 'VBP': 7, 'IN': 6, 'PRP': 4, 'RB': 4, 'VBD': 3, 'NNS': 2, 'VB': 2, 'VBZ': 2, 'DT': 2, 'VBN': 2, 'WDT': 1, 'JJR': 1, 'VBG': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 996:
# Counter({'PERSON': 12, 'ORGANIZATION': 5, 'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 996:
# Counter({'NN': 84, 'JJ': 47, 'NNP': 31, 'VBG': 11, 'VBD': 9, 'RB': 6, 'VBZ': 6, 'NNS': 5, 'VBP': 4, 'DT': 4, 'IN': 3, 'VBN': 3, 'PRP$': 2, 'JJR': 1, 'VB': 1, 'RBR': 1, 'NNPS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 997:
# Counter()
# --------------------------------------------------
# POS Tagging for Review 997:
# Counter({'NN': 3, 'JJ': 2, 'DT': 1, 'IN': 1, 'PRP': 1, 'VBG': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 998:
# Counter({'PERSON': 4, 'GPE': 2})
# --------------------------------------------------
# POS Tagging for Review 998:
# Counter({'NN': 60, 'JJ': 23, 'RB': 20, 'NNP': 17, 'VBP': 15, 'VBD': 9, 'PRP': 9, 'VBG': 8, 'VBN': 5, 'DT': 4, 'IN': 4, 'NNS': 3, 'VBZ': 2, 'JJS': 2, 'CD': 2, 'UH': 2, 'VB': 1, 'CC': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 999:
# Counter({'PERSON': 3, 'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 999:
# Counter({'NN': 23, 'JJ': 10, 'PRP': 8, 'NNP': 6, 'VBG': 5, 'RB': 5, 'VBD': 4, 'VBP': 3, 'IN': 3, 'NNS': 2, 'MD': 2, 'DT': 1, 'VBN': 1, 'VB': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 1000:
# Counter({'PERSON': 7, 'ORGANIZATION': 3})
# --------------------------------------------------
# POS Tagging for Review 1000:
# Counter({'NN': 71, 'JJ': 32, 'NNP': 24, 'VBG': 16, 'RB': 7, 'DT': 4, 'VBP': 4, 'VBZ': 3, 'IN': 3, 'VBD': 2, 'VB': 1, 'CD': 1, 'NNPS': 1, 'NNS': 1, 'JJR': 1, 'PRP$': 1, 'VBN': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 1001:
# Counter({'ORGANIZATION': 1, 'PERSON': 1})
# --------------------------------------------------
# POS Tagging for Review 1001:
# Counter({'NN': 13, 'VBG': 4, 'JJ': 3, 'NNP': 3, 'VBP': 2, 'IN': 2, 'PRP': 1, 'NNPS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 1002:
# Counter({'PERSON': 3, 'ORGANIZATION': 1})
# --------------------------------------------------
# POS Tagging for Review 1002:
# Counter({'NN': 35, 'JJ': 9, 'VBG': 9, 'NNP': 9, 'DT': 5, 'RB': 4, 'CC': 3, 'VBP': 2, 'IN': 2, 'VBZ': 2, 'WP': 1, 'VBD': 1, 'NNS': 1, 'CD': 1, 'JJS': 1, 'VB': 1, 'VBN': 1, 'RBR': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 1003:
# Counter({'PERSON': 8, 'ORGANIZATION': 3})
# --------------------------------------------------
# POS Tagging for Review 1003:
# Counter({'NN': 80, 'NNP': 24, 'JJ': 18, 'VBP': 10, 'VBG': 7, 'VBZ': 6, 'DT': 6, 'RB': 5, 'PRP': 5, 'VBD': 5, 'NNS': 4, 'IN': 4, 'VBN': 2, 'WP$': 1, 'VB': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 1004:
# Counter()
# --------------------------------------------------
# POS Tagging for Review 1004:
# Counter({'NN': 17, 'PRP': 9, 'VBD': 6, 'VBP': 6, 'JJ': 6, 'RB': 3, 'DT': 2, 'IN': 2, 'NNP': 2, 'CD': 2, 'NNS': 1, 'VBN': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 1005:
# Counter({'ORGANIZATION': 3})
# --------------------------------------------------
# POS Tagging for Review 1005:
# Counter({'NN': 17, 'JJ': 8, 'NNP': 5, 'VBP': 3, 'VBZ': 1, 'RB': 1, 'NNS': 1, 'VBD': 1, 'FW': 1, 'VBG': 1, 'IN': 1, 'JJS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 1006:
# Counter({'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 1006:
# Counter({'NN': 15, 'JJ': 11, 'VBP': 4, 'RB': 3, 'NNP': 2, 'NNS': 2, 'DT': 2, 'CD': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 1007:
# Counter()
# --------------------------------------------------
# POS Tagging for Review 1007:
# Counter({'NN': 12, 'JJ': 6, 'IN': 3, 'RB': 2, 'VBN': 1, 'VBP': 1, 'VBG': 1, 'CD': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 1008:
# Counter({'PERSON': 9, 'ORGANIZATION': 8})
# --------------------------------------------------
# POS Tagging for Review 1008:
# Counter({'NN': 103, 'JJ': 44, 'NNP': 30, 'RB': 22, 'VBP': 19, 'VBG': 17, 'VB': 17, 'IN': 12, 'VBN': 9, 'DT': 9, 'PRP': 8, 'VBZ': 6, 'NNS': 5, 'PRP$': 4, 'VBD': 4, 'JJS': 2, 'CD': 2, 'EX': 1, 'CC': 1, 'JJR': 1, 'RBR': 1, 'WP': 1, 'NNPS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 1009:
# Counter({'PERSON': 7, 'ORGANIZATION': 2, 'GPE': 1})
# --------------------------------------------------
# POS Tagging for Review 1009:
# Counter({'NN': 32, 'NNP': 24, 'JJ': 14, 'DT': 7, 'RB': 6, 'VBZ': 5, 'VBD': 4, 'VBG': 4, 'VBP': 3, 'NNS': 3, 'VBN': 2, 'IN': 2, 'WRB': 1, 'MD': 1, 'VB': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 1010:
# Counter()
# --------------------------------------------------
# POS Tagging for Review 1010:
# Counter({'RB': 4, 'NN': 4, 'JJ': 2, 'CD': 1, 'JJS': 1, 'VBD': 1, 'NNP': 1, 'PRP$': 1, 'NNS': 1, 'VBP': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 1011:
# Counter({'PERSON': 13, 'ORGANIZATION': 3})
# --------------------------------------------------
# POS Tagging for Review 1011:
# Counter({'NN': 60, 'JJ': 31, 'NNP': 30, 'VBD': 10, 'IN': 9, 'VBP': 9, 'RB': 7, 'NNS': 6, 'PRP': 5, 'VBG': 4, 'CC': 2, 'VBZ': 2, 'WRB': 1, 'VBN': 1, 'MD': 1, 'VB': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 1012:
# Counter({'PERSON': 21, 'ORGANIZATION': 3})
# --------------------------------------------------
# POS Tagging for Review 1012:
# Counter({'NN': 66, 'NNP': 47, 'JJ': 36, 'RB': 20, 'VBD': 12, 'VB': 10, 'PRP': 9, 'VBP': 9, 'IN': 8, 'NNS': 5, 'MD': 5, 'VBG': 5, 'VBN': 4, 'DT': 3, 'JJS': 3, 'CD': 2, 'CC': 2, 'WRB': 1, 'VBZ': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 1013:
# Counter()
# --------------------------------------------------
# POS Tagging for Review 1013:
# Counter({'NN': 3, 'DT': 1, 'IN': 1, 'PRP': 1, 'VBP': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 1014:
# Counter({'PERSON': 5, 'ORGANIZATION': 4})
# --------------------------------------------------
# POS Tagging for Review 1014:
# Counter({'NN': 53, 'JJ': 29, 'RB': 14, 'NNP': 11, 'VBD': 10, 'VBG': 8, 'VBN': 5, 'VBP': 5, 'DT': 3, 'IN': 3, 'PRP': 3, 'VB': 2, 'NNS': 2, 'CD': 1, 'MD': 1, 'FW': 1, 'PRP$': 1, 'JJS': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 1015:
# Counter()
# --------------------------------------------------
# POS Tagging for Review 1015:
# Counter({'NN': 5, 'JJ': 2, 'DT': 1, 'VBN': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 1016:
# Counter({'PERSON': 1})
# --------------------------------------------------
# POS Tagging for Review 1016:
# Counter({'NN': 9, 'NNP': 3, 'DT': 1, 'CC': 1, 'RB': 1, 'VBG': 1, 'JJ': 1})
# --------------------------------------------------
# Named Entity Recognition for Review 1017:
# Counter()
# --------------------------------------------------
# POS Tagging for Review 1017:
# Counter({'NN': 27, 'JJ': 12, 'RB': 8, 'PRP': 7, 'VBD': 4, 'VBN': 3, 'VBP': 3, 'VBZ': 3, 'JJS': 2, 'DT': 2, 'VBG': 2, 'NNP': 2, 'NNS': 1, 'RBR': 1, 'VB': 1, 'EX': 1})
# --------------------------------------------------

# %% [markdown]
# # Mandatory Question
#
# Provide your thoughts on the assignment. What did you find challenging, and what aspects did you enjoy? Your opinion on the provided time to complete the assignment.

# %%
# Write your response below
""" I worked on extracting the movie reviews from imdb. Extracting reviews is quite interesting
Faced some difficulties in building the code for all the questions.
One thing is when extracting the reviews from the imbd, it first scrapped the reviews that present in the page 1, I stuggled
with it as i'm getting only 27 reviews, later I recognized that the code is not loading the more reviews which I need to write code
for load more option. After that it worked.
After scraping all the reviews, the 2nd question was some what easy as it included the step to step process mentioned in
question which is easy for me to work on this.
Question 3 is bit challenging for me."""
# Out:
# " I worked on extracting the movie reviews from imdb. Extracting reviews is quite interesting\nFaced some difficulties in building the code for all the questions.\nOne thing is when extracting the reviews from the imbd, it first scrapped the reviews that present in the page 1, I stuggled \nwith it as i'm getting only 27 reviews, later I recognized that the code is not loading the more reviews which I need to write code \nfor load more option. After that it worked.\nAfter scraping all the reviews, the 2nd question was some what easy as it included the step to step process mentioned in \nquestion which is easy for me to work on this. \nQuestion 3 is bit challenging for me."
